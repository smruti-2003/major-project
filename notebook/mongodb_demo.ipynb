# %%
print("OK")
# Out:
# OK

# %%
import pandas as pd

# %%
df = pd.read_csv("dataset.csv")
df.head()
# Out:
#      datetime  datetimeEpoch  tempmax  tempmin  temp  feelslikemax  \
# 0  2024-09-07   1.725692e+09    106.1     91.0  98.5         104.0
# 1  2024-09-08   1.725779e+09    103.9     87.0  95.4         100.5
# 2  2024-09-09   1.725865e+09    105.0     83.9  94.7          99.9
# 3  2024-09-10   1.725952e+09    106.1     81.2  93.9         100.6
# 4  2024-09-11   1.726038e+09    106.1     82.1  94.0         101.0
#
#    feelslikemin  feelslike   dew  humidity  ...     City  Temp_Range  \
# 0          88.1       95.9  51.5      21.0  ...  Phoenix        15.1
# 1          84.7       92.3  48.7      21.5  ...  Phoenix        16.9
# 2          81.6       90.6  41.7      16.9  ...  Phoenix        21.1
# 3          79.5       89.8  39.1      15.7  ...  Phoenix        24.9
# 4          80.0       90.0  40.1      15.9  ...  Phoenix        24.0
#
#    Heat_Index Severity_Score  Condition_Code  Month  Season  Day_of_Week  \
# 0   95.918703         4.4300             NaN    9.0    Fall     Saturday
# 1   92.281316         3.8800             0.0    9.0    Fall       Sunday
# 2   90.599165         3.6300             0.0    9.0    Fall       Monday
# 3   89.638811         2.8512             0.0    9.0    Fall      Tuesday
# 4   89.760414         3.3908             0.0    9.0    Fall    Wednesday
#
#    Is_Weekend  Health_Risk_Score
# 0        True          10.522170
# 1        True          10.062332
# 2       False           9.673387
# 3       False           9.411519
# 4       False           9.515179
#
# [5 rows x 46 columns]

# %%
df.shape
# Out:
# (1000, 46)

# %%
df.columns
# Out:
# Index(['datetime', 'datetimeEpoch', 'tempmax', 'tempmin', 'temp',
#        'feelslikemax', 'feelslikemin', 'feelslike', 'dew', 'humidity',
#        'precip', 'precipprob', 'precipcover', 'preciptype', 'snow',
#        'snowdepth', 'windgust', 'windspeed', 'winddir', 'pressure',
#        'cloudcover', 'visibility', 'solarradiation', 'solarenergy', 'uvindex',
#        'severerisk', 'sunrise', 'sunriseEpoch', 'sunset', 'sunsetEpoch',
#        'moonphase', 'conditions', 'description', 'icon', 'stations', 'source',
#        'City', 'Temp_Range', 'Heat_Index', 'Severity_Score', 'Condition_Code',
#        'Month', 'Season', 'Day_of_Week', 'Is_Weekend', 'Health_Risk_Score'],
#       dtype='object')

# %%
data = df.to_dict(orient="records")
data
# Out:
# [{'datetime': '2024-09-07',
#   'datetimeEpoch': 1725692400.0,
#   'tempmax': 106.1,
#   'tempmin': 91.0,
#   'temp': 98.5,
#   'feelslikemax': 104.0,
#   'feelslikemin': 88.1,
#   'feelslike': 95.9,
#   'dew': 51.5,
#   'humidity': 21.0,
#   'precip': 0.0,
#   'precipprob': 5.0,
#   'precipcover': 0.0,
#   'preciptype': nan,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 26.3,
#   'windspeed': 13.7,
#   'winddir': 107.3,
#   'pressure': 1009.2,
#   'cloudcover': 25.0,
#   'visibility': 10.0,
#   'solarradiation': 261.4,
#   'solarenergy': 22.5,
#   'uvindex': 9.0,
#   'severerisk': 10.0,
#   'sunrise': '06:06:50',
#   'sunriseEpoch': 1725714410.0,
#   'sunset': '18:44:53',
#   'sunsetEpoch': 1725759893.0,
#   'moonphase': 0.16,
#   'conditions': 'Partially cloudy',
#   'description': 'Partly cloudy throughout the day.',
#   'icon': 'partly-cloudy-day',
#   'stations': "['KSDL', 'KDVT', 'AZM15', 'KPHX']",
#   'source': 'comb',
#   'City': 'Phoenix',
#   'Temp_Range': 15.099999999999994,
#   'Heat_Index': 95.91870310999995,
#   'Severity_Score': 4.43,
#   'Condition_Code': nan,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Saturday',
#   'Is_Weekend': True,
#   'Health_Risk_Score': 10.522170310999996},
#  {'datetime': '2024-09-08',
#   'datetimeEpoch': 1725778800.0,
#   'tempmax': 103.9,
#   'tempmin': 87.0,
#   'temp': 95.4,
#   'feelslikemax': 100.5,
#   'feelslikemin': 84.7,
#   'feelslike': 92.3,
#   'dew': 48.7,
#   'humidity': 21.5,
#   'precip': 0.0,
#   'precipprob': 3.0,
#   'precipcover': 0.0,
#   'preciptype': nan,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 20.8,
#   'windspeed': 12.8,
#   'winddir': 101.5,
#   'pressure': 1008.8,
#   'cloudcover': 13.5,
#   'visibility': 10.1,
#   'solarradiation': 293.3,
#   'solarenergy': 25.2,
#   'uvindex': 9.0,
#   'severerisk': 10.0,
#   'sunrise': '06:07:30',
#   'sunriseEpoch': 1725800850.0,
#   'sunset': '18:43:32',
#   'sunsetEpoch': 1725846212.0,
#   'moonphase': 0.19,
#   'conditions': 'Clear',
#   'description': 'Clear conditions throughout the day.',
#   'icon': 'clear-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'Phoenix',
#   'Temp_Range': 16.900000000000006,
#   'Heat_Index': 92.28131624140006,
#   'Severity_Score': 3.88,
#   'Condition_Code': 0.0,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Sunday',
#   'Is_Weekend': True,
#   'Health_Risk_Score': 10.062331624140006},
#  {'datetime': '2024-09-09',
#   'datetimeEpoch': 1725865200.0,
#   'tempmax': 105.0,
#   'tempmin': 83.9,
#   'temp': 94.7,
#   'feelslikemax': 99.9,
#   'feelslikemin': 81.6,
#   'feelslike': 90.6,
#   'dew': 41.7,
#   'humidity': 16.9,
#   'precip': 0.0,
#   'precipprob': 0.0,
#   'precipcover': 0.0,
#   'preciptype': nan,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 18.3,
#   'windspeed': 10.3,
#   'winddir': 90.8,
#   'pressure': 1009.4,
#   'cloudcover': 6.2,
#   'visibility': 10.1,
#   'solarradiation': 327.0,
#   'solarenergy': 28.2,
#   'uvindex': 9.0,
#   'severerisk': 10.0,
#   'sunrise': '06:08:10',
#   'sunriseEpoch': 1725887290.0,
#   'sunset': '18:42:10',
#   'sunsetEpoch': 1725932530.0,
#   'moonphase': 0.22,
#   'conditions': 'Clear',
#   'description': 'Clear conditions throughout the day.',
#   'icon': 'clear-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'Phoenix',
#   'Temp_Range': 21.099999999999994,
#   'Heat_Index': 90.5991651058291,
#   'Severity_Score': 3.63,
#   'Condition_Code': 0.0,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Monday',
#   'Is_Weekend': False,
#   'Health_Risk_Score': 9.67338651058291},
#  {'datetime': '2024-09-10',
#   'datetimeEpoch': 1725951600.0,
#   'tempmax': 106.1,
#   'tempmin': 81.2,
#   'temp': 93.9,
#   'feelslikemax': 100.6,
#   'feelslikemin': 79.5,
#   'feelslike': 89.8,
#   'dew': 39.1,
#   'humidity': 15.7,
#   'precip': 0.012,
#   'precipprob': 0.0,
#   'precipcover': 4.17,
#   'preciptype': "['rain']",
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 10.5,
#   'windspeed': 5.4,
#   'winddir': 130.1,
#   'pressure': 1006.8,
#   'cloudcover': 4.9,
#   'visibility': 12.5,
#   'solarradiation': 276.8,
#   'solarenergy': 24.0,
#   'uvindex': 9.0,
#   'severerisk': 10.0,
#   'sunrise': '06:08:49',
#   'sunriseEpoch': 1725973729.0,
#   'sunset': '18:40:48',
#   'sunsetEpoch': 1726018848.0,
#   'moonphase': 0.25,
#   'conditions': 'Clear',
#   'description': 'Clear conditions throughout the day.',
#   'icon': 'clear-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'Phoenix',
#   'Temp_Range': 24.89999999999999,
#   'Heat_Index': 89.6388106900291,
#   'Severity_Score': 2.8512000000000004,
#   'Condition_Code': 0.0,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Tuesday',
#   'Is_Weekend': False,
#   'Health_Risk_Score': 9.411519469002911},
#  {'datetime': '2024-09-11',
#   'datetimeEpoch': 1726038000.0,
#   'tempmax': 106.1,
#   'tempmin': 82.1,
#   'temp': 94.0,
#   'feelslikemax': 101.0,
#   'feelslikemin': 80.0,
#   'feelslike': 90.0,
#   'dew': 40.1,
#   'humidity': 15.9,
#   'precip': 0.008,
#   'precipprob': 0.0,
#   'precipcover': 4.17,
#   'preciptype': "['rain']",
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 15.9,
#   'windspeed': 8.1,
#   'winddir': 201.6,
#   'pressure': 1001.8,
#   'cloudcover': 5.7,
#   'visibility': 15.0,
#   'solarradiation': 274.9,
#   'solarenergy': 23.7,
#   'uvindex': 9.0,
#   'severerisk': 10.0,
#   'sunrise': '06:09:29',
#   'sunriseEpoch': 1726060169.0,
#   'sunset': '18:39:26',
#   'sunsetEpoch': 1726105166.0,
#   'moonphase': 0.29,
#   'conditions': 'Clear',
#   'description': 'Clear conditions throughout the day.',
#   'icon': 'clear-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'Phoenix',
#   'Temp_Range': 24.0,
#   'Heat_Index': 89.76041382170003,
#   'Severity_Score': 3.3908,
#   'Condition_Code': 0.0,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Wednesday',
#   'Is_Weekend': False,
#   'Health_Risk_Score': 9.515178582170003},
#  {'datetime': '2024-09-12',
#   'datetimeEpoch': 1726124400.0,
#   'tempmax': 103.0,
#   'tempmin': 81.6,
#   'temp': 91.5,
#   'feelslikemax': 98.1,
#   'feelslikemin': 79.9,
#   'feelslike': 87.9,
#   'dew': 41.6,
#   'humidity': 18.4,
#   'precip': 0.0,
#   'precipprob': 0.0,
#   'precipcover': 0.0,
#   'preciptype': nan,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 21.5,
#   'windspeed': 10.7,
#   'winddir': 201.9,
#   'pressure': 1000.8,
#   'cloudcover': 4.0,
#   'visibility': 15.0,
#   'solarradiation': 272.7,
#   'solarenergy': 23.6,
#   'uvindex': 9.0,
#   'severerisk': 10.0,
#   'sunrise': '06:10:09',
#   'sunriseEpoch': 1726146609.0,
#   'sunset': '18:38:04',
#   'sunsetEpoch': 1726191484.0,
#   'moonphase': 0.32,
#   'conditions': 'Clear',
#   'description': 'Clear conditions throughout the day.',
#   'icon': 'clear-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'Phoenix',
#   'Temp_Range': 21.40000000000001,
#   'Heat_Index': 87.60290690670004,
#   'Severity_Score': 3.95,
#   'Condition_Code': 0.0,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Thursday',
#   'Is_Weekend': False,
#   'Health_Risk_Score': 9.487090690670003},
#  {'datetime': '2024-09-13',
#   'datetimeEpoch': 1726210800.0,
#   'tempmax': 101.2,
#   'tempmin': 77.6,
#   'temp': 89.3,
#   'feelslikemax': 96.9,
#   'feelslikemin': 77.6,
#   'feelslike': 86.4,
#   'dew': 42.6,
#   'humidity': 20.4,
#   'precip': 0.0,
#   'precipprob': 0.0,
#   'precipcover': 0.0,
#   'preciptype': nan,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 14.3,
#   'windspeed': 7.2,
#   'winddir': 192.9,
#   'pressure': 1006.3,
#   'cloudcover': 7.2,
#   'visibility': 15.0,
#   'solarradiation': 269.5,
#   'solarenergy': 23.1,
#   'uvindex': 9.0,
#   'severerisk': 10.0,
#   'sunrise': '06:10:49',
#   'sunriseEpoch': 1726233049.0,
#   'sunset': '18:36:41',
#   'sunsetEpoch': 1726277801.0,
#   'moonphase': 0.36,
#   'conditions': 'Clear',
#   'description': 'Clear conditions throughout the day.',
#   'icon': 'clear-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'Phoenix',
#   'Temp_Range': 23.60000000000001,
#   'Heat_Index': 85.71988263588409,
#   'Severity_Score': 3.2300000000000004,
#   'Condition_Code': 0.0,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Friday',
#   'Is_Weekend': False,
#   'Health_Risk_Score': 9.23090826358841},
#  {'datetime': '2024-09-14',
#   'datetimeEpoch': 1726297200.0,
#   'tempmax': 99.4,
#   'tempmin': 78.2,
#   'temp': 89.1,
#   'feelslikemax': 96.1,
#   'feelslikemin': 78.2,
#   'feelslike': 86.8,
#   'dew': 48.4,
#   'humidity': 25.3,
#   'precip': 0.004,
#   'precipprob': 6.0,
#   'precipcover': 4.17,
#   'preciptype': "['rain']",
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 12.1,
#   'windspeed': 5.4,
#   'winddir': 224.8,
#   'pressure': 1008.7,
#   'cloudcover': 9.6,
#   'visibility': 15.0,
#   'solarradiation': 262.5,
#   'solarenergy': 22.6,
#   'uvindex': 9.0,
#   'severerisk': 10.0,
#   'sunrise': '06:11:29',
#   'sunriseEpoch': 1726319489.0,
#   'sunset': '18:35:19',
#   'sunsetEpoch': 1726364119.0,
#   'moonphase': 0.39,
#   'conditions': 'Clear',
#   'description': 'Clear conditions throughout the day.',
#   'icon': 'clear-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'Phoenix',
#   'Temp_Range': 21.200000000000003,
#   'Heat_Index': 86.11250590362911,
#   'Severity_Score': 3.0104,
#   'Condition_Code': 0.0,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Saturday',
#   'Is_Weekend': True,
#   'Health_Risk_Score': 9.37288179036291},
#  {'datetime': '2024-09-15',
#   'datetimeEpoch': 1726383600.0,
#   'tempmax': 100.1,
#   'tempmin': 82.1,
#   'temp': 92.0,
#   'feelslikemax': 100.6,
#   'feelslikemin': 81.5,
#   'feelslike': 92.3,
#   'dew': 60.3,
#   'humidity': 35.8,
#   'precip': 0.012,
#   'precipprob': 12.9,
#   'precipcover': 4.17,
#   'preciptype': "['rain']",
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 19.0,
#   'windspeed': 11.6,
#   'winddir': 254.3,
#   'pressure': 1007.3,
#   'cloudcover': 1.8,
#   'visibility': 14.0,
#   'solarradiation': 259.9,
#   'solarenergy': 22.3,
#   'uvindex': 8.0,
#   'severerisk': 30.0,
#   'sunrise': '06:12:09',
#   'sunriseEpoch': 1726405929.0,
#   'sunset': '18:33:56',
#   'sunsetEpoch': 1726450436.0,
#   'moonphase': 0.42,
#   'conditions': 'Clear',
#   'description': 'Clear conditions throughout the day.',
#   'icon': 'clear-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'Phoenix',
#   'Temp_Range': 18.0,
#   'Heat_Index': 92.16758603040012,
#   'Severity_Score': 3.5012,
#   'Condition_Code': 0.0,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Sunday',
#   'Is_Weekend': True,
#   'Health_Risk_Score': 10.470188203040012},
#  {'datetime': '2024-09-16',
#   'datetimeEpoch': 1726470000.0,
#   'tempmax': 99.6,
#   'tempmin': 86.1,
#   'temp': 92.2,
#   'feelslikemax': 99.7,
#   'feelslikemin': 87.4,
#   'feelslike': 93.0,
#   'dew': 62.2,
#   'humidity': 37.8,
#   'precip': 0.0,
#   'precipprob': 12.9,
#   'precipcover': 0.0,
#   'preciptype': nan,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 17.7,
#   'windspeed': 12.1,
#   'winddir': 222.5,
#   'pressure': 1006.8,
#   'cloudcover': 12.2,
#   'visibility': 15.0,
#   'solarradiation': 245.3,
#   'solarenergy': 21.3,
#   'uvindex': 8.0,
#   'severerisk': 30.0,
#   'sunrise': '06:12:49',
#   'sunriseEpoch': 1726492369.0,
#   'sunset': '18:32:33',
#   'sunsetEpoch': 1726536753.0,
#   'moonphase': 0.46,
#   'conditions': 'Clear',
#   'description': 'Clear conditions throughout the day.',
#   'icon': 'clear-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'Phoenix',
#   'Temp_Range': 13.5,
#   'Heat_Index': 93.20895235529596,
#   'Severity_Score': 3.37,
#   'Condition_Code': 0.0,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Monday',
#   'Is_Weekend': False,
#   'Health_Risk_Score': 10.594755235529597},
#  {'datetime': '2024-09-17',
#   'datetimeEpoch': 1726556400.0,
#   'tempmax': 100.7,
#   'tempmin': 85.7,
#   'temp': 92.2,
#   'feelslikemax': 98.5,
#   'feelslikemin': 85.2,
#   'feelslike': 91.2,
#   'dew': 57.3,
#   'humidity': 31.8,
#   'precip': 0.0,
#   'precipprob': 19.4,
#   'precipcover': 0.0,
#   'preciptype': nan,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 21.5,
#   'windspeed': 18.3,
#   'winddir': 234.6,
#   'pressure': 1005.6,
#   'cloudcover': 34.7,
#   'visibility': 15.0,
#   'solarradiation': 246.5,
#   'solarenergy': 21.2,
#   'uvindex': 8.0,
#   'severerisk': 10.0,
#   'sunrise': '06:13:29',
#   'sunriseEpoch': 1726578809.0,
#   'sunset': '18:31:10',
#   'sunsetEpoch': 1726623070.0,
#   'moonphase': 0.5,
#   'conditions': 'Partially cloudy',
#   'description': 'Partly cloudy throughout the day.',
#   'icon': 'partly-cloudy-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'Phoenix',
#   'Temp_Range': 15.0,
#   'Heat_Index': 91.13188727945612,
#   'Severity_Score': 3.75,
#   'Condition_Code': nan,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Tuesday',
#   'Is_Weekend': False,
#   'Health_Risk_Score': 10.305688727945611},
#  {'datetime': '2024-09-18',
#   'datetimeEpoch': 1726642800.0,
#   'tempmax': 98.3,
#   'tempmin': 83.2,
#   'temp': 90.1,
#   'feelslikemax': 93.5,
#   'feelslikemin': 80.7,
#   'feelslike': 86.4,
#   'dew': 39.2,
#   'humidity': 17.4,
#   'precip': 0.0,
#   'precipprob': 6.5,
#   'precipcover': 0.0,
#   'preciptype': nan,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 15.7,
#   'windspeed': 10.1,
#   'winddir': 247.2,
#   'pressure': 1007.1,
#   'cloudcover': 0.0,
#   'visibility': 15.0,
#   'solarradiation': 267.3,
#   'solarenergy': 23.1,
#   'uvindex': 9.0,
#   'severerisk': 10.0,
#   'sunrise': '06:14:09',
#   'sunriseEpoch': 1726665249.0,
#   'sunset': '18:29:47',
#   'sunsetEpoch': 1726709387.0,
#   'moonphase': 0.52,
#   'conditions': 'Clear',
#   'description': 'Clear conditions throughout the day.',
#   'icon': 'clear-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'Phoenix',
#   'Temp_Range': 15.099999999999994,
#   'Heat_Index': 86.20360304705606,
#   'Severity_Score': 3.37,
#   'Condition_Code': 0.0,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Wednesday',
#   'Is_Weekend': False,
#   'Health_Risk_Score': 9.206740304705606},
#  {'datetime': '2024-09-19',
#   'datetimeEpoch': 1726729200.0,
#   'tempmax': 97.4,
#   'tempmin': 81.8,
#   'temp': 89.1,
#   'feelslikemax': 92.2,
#   'feelslikemin': 79.6,
#   'feelslike': 85.3,
#   'dew': 29.0,
#   'humidity': 12.4,
#   'precip': 0.0,
#   'precipprob': 6.5,
#   'precipcover': 0.0,
#   'preciptype': nan,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 12.5,
#   'windspeed': 8.7,
#   'winddir': 258.9,
#   'pressure': 1007.8,
#   'cloudcover': 9.6,
#   'visibility': 15.0,
#   'solarradiation': 271.1,
#   'solarenergy': 23.4,
#   'uvindex': 9.0,
#   'severerisk': 10.0,
#   'sunrise': '06:14:50',
#   'sunriseEpoch': 1726751690.0,
#   'sunset': '18:28:24',
#   'sunsetEpoch': 1726795704.0,
#   'moonphase': 0.56,
#   'conditions': 'Clear',
#   'description': 'Clear conditions throughout the day.',
#   'icon': 'clear-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'Phoenix',
#   'Temp_Range': 15.600000000000009,
#   'Heat_Index': 85.14708197583606,
#   'Severity_Score': 3.05,
#   'Condition_Code': 0.0,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Thursday',
#   'Is_Weekend': False,
#   'Health_Risk_Score': 8.892908197583605},
#  {'datetime': '2024-09-20',
#   'datetimeEpoch': 1726815600.0,
#   'tempmax': 94.6,
#   'tempmin': 82.5,
#   'temp': 87.9,
#   'feelslikemax': 89.9,
#   'feelslikemin': 80.1,
#   'feelslike': 84.4,
#   'dew': 35.5,
#   'humidity': 15.8,
#   'precip': 0.004,
#   'precipprob': 6.5,
#   'precipcover': 4.17,
#   'preciptype': "['rain']",
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 15.4,
#   'windspeed': 9.8,
#   'winddir': 238.1,
#   'pressure': 1007.4,
#   'cloudcover': 92.0,
#   'visibility': 15.0,
#   'solarradiation': 175.8,
#   'solarenergy': 15.3,
#   'uvindex': 6.0,
#   'severerisk': 10.0,
#   'sunrise': '06:15:30',
#   'sunriseEpoch': 1726838130.0,
#   'sunset': '18:27:01',
#   'sunsetEpoch': 1726882021.0,
#   'moonphase': 0.59,
#   'conditions': 'Overcast',
#   'description': 'Cloudy skies throughout the day.',
#   'icon': 'cloudy',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'Phoenix',
#   'Temp_Range': 12.099999999999994,
#   'Heat_Index': 84.20944151646408,
#   'Severity_Score': 2.7404,
#   'Condition_Code': nan,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Friday',
#   'Is_Weekend': False,
#   'Health_Risk_Score': 8.853927351646409},
#  {'datetime': '2024-09-21',
#   'datetimeEpoch': 1726902000.0,
#   'tempmax': 93.6,
#   'tempmin': 77.4,
#   'temp': 85.8,
#   'feelslikemax': 89.0,
#   'feelslikemin': 77.4,
#   'feelslike': 83.1,
#   'dew': 28.7,
#   'humidity': 13.7,
#   'precip': 0.0,
#   'precipprob': 3.2,
#   'precipcover': 0.0,
#   'preciptype': nan,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 14.1,
#   'windspeed': 9.2,
#   'winddir': 271.6,
#   'pressure': 1009.3,
#   'cloudcover': 1.8,
#   'visibility': 15.0,
#   'solarradiation': 268.6,
#   'solarenergy': 23.3,
#   'uvindex': 9.0,
#   'severerisk': 10.0,
#   'sunrise': '06:16:10',
#   'sunriseEpoch': 1726924570.0,
#   'sunset': '18:25:39',
#   'sunsetEpoch': 1726968339.0,
#   'moonphase': 0.63,
#   'conditions': 'Clear',
#   'description': 'Clear conditions throughout the day.',
#   'icon': 'clear-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'Phoenix',
#   'Temp_Range': 16.19999999999999,
#   'Heat_Index': 82.48084148677607,
#   'Severity_Score': 3.21,
#   'Condition_Code': 0.0,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Saturday',
#   'Is_Weekend': True,
#   'Health_Risk_Score': 8.687854148677607},
#  {'datetime': '2024-09-07',
#   'datetimeEpoch': 1725692400.0,
#   'tempmax': 89.0,
#   'tempmin': 62.1,
#   'temp': 73.3,
#   'feelslikemax': 88.6,
#   'feelslikemin': 62.1,
#   'feelslike': 73.3,
#   'dew': 59.8,
#   'humidity': 66.3,
#   'precip': 0.0,
#   'precipprob': 0.0,
#   'precipcover': 0.0,
#   'preciptype': nan,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 16.1,
#   'windspeed': 9.2,
#   'winddir': 311.1,
#   'pressure': 1012.2,
#   'cloudcover': 12.0,
#   'visibility': 10.0,
#   'solarradiation': 267.7,
#   'solarenergy': 23.4,
#   'uvindex': 9.0,
#   'severerisk': 10.0,
#   'sunrise': '06:43:31',
#   'sunriseEpoch': 1725716611.0,
#   'sunset': '19:26:34',
#   'sunsetEpoch': 1725762394.0,
#   'moonphase': 0.16,
#   'conditions': 'Clear',
#   'description': 'Clear conditions throughout the day.',
#   'icon': 'clear-day',
#   'stations': "['KSJC', 'KLVK', 'E6873', 'KHWD', 'KWVI', 'KOAK']",
#   'source': 'comb',
#   'City': 'San Jose',
#   'Temp_Range': 26.9,
#   'Heat_Index': 75.84249614266135,
#   'Severity_Score': 3.41,
#   'Condition_Code': 0.0,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Saturday',
#   'Is_Weekend': True,
#   'Health_Risk_Score': 9.845079614266137},
#  {'datetime': '2024-09-08',
#   'datetimeEpoch': 1725778800.0,
#   'tempmax': 89.0,
#   'tempmin': 60.0,
#   'temp': 72.4,
#   'feelslikemax': 87.9,
#   'feelslikemin': 60.0,
#   'feelslike': 72.3,
#   'dew': 57.6,
#   'humidity': 62.5,
#   'precip': 0.0,
#   'precipprob': 0.0,
#   'precipcover': 0.0,
#   'preciptype': nan,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 13.9,
#   'windspeed': 8.1,
#   'winddir': 310.2,
#   'pressure': 1012.1,
#   'cloudcover': 15.6,
#   'visibility': 9.8,
#   'solarradiation': 279.0,
#   'solarenergy': 24.1,
#   'uvindex': 9.0,
#   'severerisk': 10.0,
#   'sunrise': '06:44:20',
#   'sunriseEpoch': 1725803060.0,
#   'sunset': '19:25:03',
#   'sunsetEpoch': 1725848703.0,
#   'moonphase': 0.19,
#   'conditions': 'Clear',
#   'description': 'Clear conditions throughout the day.',
#   'icon': 'clear-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'San Jose',
#   'Temp_Range': 29.0,
#   'Heat_Index': 75.92701658370012,
#   'Severity_Score': 3.1900000000000004,
#   'Condition_Code': 0.0,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Sunday',
#   'Is_Weekend': True,
#   'Health_Risk_Score': 9.586451658370011},
#  {'datetime': '2024-09-09',
#   'datetimeEpoch': 1725865200.0,
#   'tempmax': 88.1,
#   'tempmin': 63.1,
#   'temp': 73.1,
#   'feelslikemax': 87.4,
#   'feelslikemin': 63.1,
#   'feelslike': 73.0,
#   'dew': 57.4,
#   'humidity': 59.9,
#   'precip': 0.0,
#   'precipprob': 0.0,
#   'precipcover': 0.0,
#   'preciptype': nan,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 16.1,
#   'windspeed': 9.2,
#   'winddir': 296.7,
#   'pressure': 1013.0,
#   'cloudcover': 11.0,
#   'visibility': 10.1,
#   'solarradiation': 311.5,
#   'solarenergy': 27.0,
#   'uvindex': 9.0,
#   'severerisk': 10.0,
#   'sunrise': '06:45:10',
#   'sunriseEpoch': 1725889510.0,
#   'sunset': '19:23:32',
#   'sunsetEpoch': 1725935012.0,
#   'moonphase': 0.22,
#   'conditions': 'Clear',
#   'description': 'Clear conditions throughout the day.',
#   'icon': 'clear-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'San Jose',
#   'Temp_Range': 25.0,
#   'Heat_Index': 76.45640756034118,
#   'Severity_Score': 3.41,
#   'Condition_Code': 0.0,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Monday',
#   'Is_Weekend': False,
#   'Health_Risk_Score': 9.688230756034118},
#  {'datetime': '2024-09-10',
#   'datetimeEpoch': 1725951600.0,
#   'tempmax': 79.4,
#   'tempmin': 59.6,
#   'temp': 67.8,
#   'feelslikemax': 79.4,
#   'feelslikemin': 59.6,
#   'feelslike': 67.8,
#   'dew': 57.2,
#   'humidity': 70.7,
#   'precip': 0.0,
#   'precipprob': 0.0,
#   'precipcover': 0.0,
#   'preciptype': nan,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 17.4,
#   'windspeed': 9.8,
#   'winddir': 290.2,
#   'pressure': 1012.5,
#   'cloudcover': 18.8,
#   'visibility': 12.4,
#   'solarradiation': 274.7,
#   'solarenergy': 23.8,
#   'uvindex': 9.0,
#   'severerisk': 10.0,
#   'sunrise': '06:45:59',
#   'sunriseEpoch': 1725975959.0,
#   'sunset': '19:22:01',
#   'sunsetEpoch': 1726021321.0,
#   'moonphase': 0.25,
#   'conditions': 'Clear',
#   'description': 'Clear conditions throughout the day.',
#   'icon': 'clear-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'San Jose',
#   'Temp_Range': 19.800000000000004,
#   'Heat_Index': 73.51643181157598,
#   'Severity_Score': 3.54,
#   'Condition_Code': 0.0,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Tuesday',
#   'Is_Weekend': False,
#   'Health_Risk_Score': 9.8544231811576},
#  {'datetime': '2024-09-11',
#   'datetimeEpoch': 1726038000.0,
#   'tempmax': 77.3,
#   'tempmin': 57.6,
#   'temp': 66.3,
#   'feelslikemax': 77.3,
#   'feelslikemin': 57.6,
#   'feelslike': 66.3,
#   'dew': 56.8,
#   'humidity': 73.1,
#   'precip': 0.0,
#   'precipprob': 4.0,
#   'precipcover': 0.0,
#   'preciptype': nan,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 23.0,
#   'windspeed': 13.4,
#   'winddir': 273.9,
#   'pressure': 1009.6,
#   'cloudcover': 17.3,
#   'visibility': 15.0,
#   'solarradiation': 264.0,
#   'solarenergy': 22.6,
#   'uvindex': 8.0,
#   'severerisk': 10.0,
#   'sunrise': '06:46:48',
#   'sunriseEpoch': 1726062408.0,
#   'sunset': '19:20:29',
#   'sunsetEpoch': 1726107629.0,
#   'moonphase': 0.29,
#   'conditions': 'Clear',
#   'description': 'Clear conditions throughout the day.',
#   'icon': 'clear-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'San Jose',
#   'Temp_Range': 19.7,
#   'Heat_Index': 72.90603255502886,
#   'Severity_Score': 3.9,
#   'Condition_Code': 0.0,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Wednesday',
#   'Is_Weekend': False,
#   'Health_Risk_Score': 10.141503255502885},
#  {'datetime': '2024-09-12',
#   'datetimeEpoch': 1726124400.0,
#   'tempmax': 79.2,
#   'tempmin': 57.8,
#   'temp': 67.4,
#   'feelslikemax': 79.2,
#   'feelslikemin': 57.8,
#   'feelslike': 67.4,
#   'dew': 55.6,
#   'humidity': 68.3,
#   'precip': 0.0,
#   'precipprob': 5.0,
#   'precipcover': 0.0,
#   'preciptype': nan,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 17.9,
#   'windspeed': 10.7,
#   'winddir': 285.8,
#   'pressure': 1007.0,
#   'cloudcover': 14.2,
#   'visibility': 15.0,
#   'solarradiation': 262.2,
#   'solarenergy': 22.6,
#   'uvindex': 8.0,
#   'severerisk': 10.0,
#   'sunrise': '06:47:38',
#   'sunriseEpoch': 1726148858.0,
#   'sunset': '19:18:57',
#   'sunsetEpoch': 1726193937.0,
#   'moonphase': 0.32,
#   'conditions': 'Clear',
#   'description': 'Clear conditions throughout the day.',
#   'icon': 'clear-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'San Jose',
#   'Temp_Range': 21.40000000000001,
#   'Heat_Index': 74.30085574530415,
#   'Severity_Score': 3.39,
#   'Condition_Code': 0.0,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Thursday',
#   'Is_Weekend': False,
#   'Health_Risk_Score': 9.745455574530414},
#  {'datetime': '2024-09-13',
#   'datetimeEpoch': 1726210800.0,
#   'tempmax': 83.2,
#   'tempmin': 58.9,
#   'temp': 69.6,
#   'feelslikemax': 82.2,
#   'feelslikemin': 58.9,
#   'feelslike': 69.5,
#   'dew': 54.2,
#   'humidity': 60.5,
#   'precip': 0.0,
#   'precipprob': 0.0,
#   'precipcover': 0.0,
#   'preciptype': nan,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 16.1,
#   'windspeed': 8.9,
#   'winddir': 287.5,
#   'pressure': 1007.4,
#   'cloudcover': 5.9,
#   'visibility': 15.0,
#   'solarradiation': 263.2,
#   'solarenergy': 22.5,
#   'uvindex': 8.0,
#   'severerisk': 10.0,
#   'sunrise': '06:48:27',
#   'sunriseEpoch': 1726235307.0,
#   'sunset': '19:17:25',
#   'sunsetEpoch': 1726280245.0,
#   'moonphase': 0.36,
#   'conditions': 'Clear',
#   'description': 'Clear conditions throughout the day.',
#   'icon': 'clear-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'San Jose',
#   'Temp_Range': 24.300000000000004,
#   'Heat_Index': 75.81915810730015,
#   'Severity_Score': 3.21,
#   'Condition_Code': 0.0,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Friday',
#   'Is_Weekend': False,
#   'Health_Risk_Score': 9.523965810730015},
#  {'datetime': '2024-09-14',
#   'datetimeEpoch': 1726297200.0,
#   'tempmax': 81.4,
#   'tempmin': 59.4,
#   'temp': 68.8,
#   'feelslikemax': 81.3,
#   'feelslikemin': 59.4,
#   'feelslike': 68.8,
#   'dew': 55.5,
#   'humidity': 64.2,
#   'precip': 0.0,
#   'precipprob': 1.0,
#   'precipcover': 0.0,
#   'preciptype': nan,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 16.6,
#   'windspeed': 9.8,
#   'winddir': 263.1,
#   'pressure': 1010.3,
#   'cloudcover': 8.9,
#   'visibility': 14.9,
#   'solarradiation': 259.1,
#   'solarenergy': 22.3,
#   'uvindex': 8.0,
#   'severerisk': 10.0,
#   'sunrise': '06:49:17',
#   'sunriseEpoch': 1726321757.0,
#   'sunset': '19:15:53',
#   'sunsetEpoch': 1726366553.0,
#   'moonphase': 0.39,
#   'conditions': 'Clear',
#   'description': 'Clear conditions throughout the day.',
#   'icon': 'clear-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'San Jose',
#   'Temp_Range': 22.000000000000007,
#   'Heat_Index': 75.16348200137604,
#   'Severity_Score': 3.26,
#   'Condition_Code': 0.0,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Saturday',
#   'Is_Weekend': True,
#   'Health_Risk_Score': 9.609268200137604},
#  {'datetime': '2024-09-15',
#   'datetimeEpoch': 1726383600.0,
#   'tempmax': 78.3,
#   'tempmin': 59.8,
#   'temp': 66.8,
#   'feelslikemax': 78.3,
#   'feelslikemin': 59.8,
#   'feelslike': 66.8,
#   'dew': 47.3,
#   'humidity': 52.9,
#   'precip': 0.0,
#   'precipprob': 3.2,
#   'precipcover': 0.0,
#   'preciptype': nan,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 9.8,
#   'windspeed': 8.9,
#   'winddir': 256.5,
#   'pressure': 1011.5,
#   'cloudcover': 3.1,
#   'visibility': 14.9,
#   'solarradiation': 255.1,
#   'solarenergy': 22.0,
#   'uvindex': 8.0,
#   'severerisk': 10.0,
#   'sunrise': '06:50:06',
#   'sunriseEpoch': 1726408206.0,
#   'sunset': '19:14:21',
#   'sunsetEpoch': 1726452861.0,
#   'moonphase': 0.42,
#   'conditions': 'Clear',
#   'description': 'Clear conditions throughout the day.',
#   'icon': 'clear-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'San Jose',
#   'Temp_Range': 18.5,
#   'Heat_Index': 77.56033359368409,
#   'Severity_Score': 2.58,
#   'Condition_Code': 0.0,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Sunday',
#   'Is_Weekend': True,
#   'Health_Risk_Score': 9.12085335936841},
#  {'datetime': '2024-09-16',
#   'datetimeEpoch': 1726470000.0,
#   'tempmax': 81.2,
#   'tempmin': 59.3,
#   'temp': 68.9,
#   'feelslikemax': 79.6,
#   'feelslikemin': 59.3,
#   'feelslike': 68.6,
#   'dew': 44.4,
#   'humidity': 43.5,
#   'precip': 0.0,
#   'precipprob': 0.0,
#   'precipcover': 0.0,
#   'preciptype': nan,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 7.8,
#   'windspeed': 8.1,
#   'winddir': 287.5,
#   'pressure': 1010.1,
#   'cloudcover': 8.6,
#   'visibility': 15.0,
#   'solarradiation': 249.6,
#   'solarenergy': 21.7,
#   'uvindex': 8.0,
#   'severerisk': 10.0,
#   'sunrise': '06:50:56',
#   'sunriseEpoch': 1726494656.0,
#   'sunset': '19:12:49',
#   'sunsetEpoch': 1726539169.0,
#   'moonphase': 0.46,
#   'conditions': 'Clear',
#   'description': 'Clear conditions throughout the day.',
#   'icon': 'clear-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'San Jose',
#   'Temp_Range': 21.90000000000001,
#   'Heat_Index': 77.26954857032499,
#   'Severity_Score': 2.38,
#   'Condition_Code': 0.0,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Monday',
#   'Is_Weekend': False,
#   'Health_Risk_Score': 8.762254857032499},
#  {'datetime': '2024-09-17',
#   'datetimeEpoch': 1726556400.0,
#   'tempmax': 82.3,
#   'tempmin': 60.9,
#   'temp': 68.5,
#   'feelslikemax': 80.2,
#   'feelslikemin': 60.9,
#   'feelslike': 68.4,
#   'dew': 46.6,
#   'humidity': 47.6,
#   'precip': 0.0,
#   'precipprob': 0.0,
#   'precipcover': 0.0,
#   'preciptype': nan,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 8.5,
#   'windspeed': 10.3,
#   'winddir': 279.9,
#   'pressure': 1009.1,
#   'cloudcover': 14.2,
#   'visibility': 14.9,
#   'solarradiation': 245.6,
#   'solarenergy': 21.3,
#   'uvindex': 8.0,
#   'severerisk': 10.0,
#   'sunrise': '06:51:45',
#   'sunriseEpoch': 1726581105.0,
#   'sunset': '19:11:16',
#   'sunsetEpoch': 1726625476.0,
#   'moonphase': 0.5,
#   'conditions': 'Clear',
#   'description': 'Clear conditions throughout the day.',
#   'icon': 'clear-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'San Jose',
#   'Temp_Range': 21.4,
#   'Heat_Index': 77.32153682110014,
#   'Severity_Score': 2.45,
#   'Condition_Code': 0.0,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Tuesday',
#   'Is_Weekend': False,
#   'Health_Risk_Score': 8.898353682110015},
#  {'datetime': '2024-09-18',
#   'datetimeEpoch': 1726642800.0,
#   'tempmax': 76.9,
#   'tempmin': 57.6,
#   'temp': 64.9,
#   'feelslikemax': 76.9,
#   'feelslikemin': 57.6,
#   'feelslike': 64.9,
#   'dew': 49.2,
#   'humidity': 58.3,
#   'precip': 0.0,
#   'precipprob': 0.0,
#   'precipcover': 0.0,
#   'preciptype': nan,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 9.2,
#   'windspeed': 10.7,
#   'winddir': 277.8,
#   'pressure': 1011.5,
#   'cloudcover': 20.0,
#   'visibility': 14.9,
#   'solarradiation': 241.5,
#   'solarenergy': 20.9,
#   'uvindex': 8.0,
#   'severerisk': 10.0,
#   'sunrise': '06:52:35',
#   'sunriseEpoch': 1726667555.0,
#   'sunset': '19:09:44',
#   'sunsetEpoch': 1726711784.0,
#   'moonphase': 0.52,
#   'conditions': 'Clear',
#   'description': 'Becoming cloudy in the afternoon.',
#   'icon': 'clear-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'San Jose',
#   'Temp_Range': 19.300000000000004,
#   'Heat_Index': 77.801748442029,
#   'Severity_Score': 2.52,
#   'Condition_Code': 0.0,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Wednesday',
#   'Is_Weekend': False,
#   'Health_Risk_Score': 9.2493348442029},
#  {'datetime': '2024-09-19',
#   'datetimeEpoch': 1726729200.0,
#   'tempmax': 75.5,
#   'tempmin': 57.6,
#   'temp': 64.7,
#   'feelslikemax': 75.5,
#   'feelslikemin': 57.6,
#   'feelslike': 64.7,
#   'dew': 48.5,
#   'humidity': 57.7,
#   'precip': 0.0,
#   'precipprob': 3.2,
#   'precipcover': 0.0,
#   'preciptype': nan,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 8.3,
#   'windspeed': 8.7,
#   'winddir': 290.8,
#   'pressure': 1012.7,
#   'cloudcover': 0.1,
#   'visibility': 14.8,
#   'solarradiation': 240.3,
#   'solarenergy': 20.9,
#   'uvindex': 8.0,
#   'severerisk': 10.0,
#   'sunrise': '06:53:25',
#   'sunriseEpoch': 1726754005.0,
#   'sunset': '19:08:11',
#   'sunsetEpoch': 1726798091.0,
#   'moonphase': 0.56,
#   'conditions': 'Clear',
#   'description': 'Clear conditions throughout the day.',
#   'icon': 'clear-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'San Jose',
#   'Temp_Range': 17.9,
#   'Heat_Index': 78.03617693414107,
#   'Severity_Score': 2.43,
#   'Condition_Code': 0.0,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Thursday',
#   'Is_Weekend': False,
#   'Health_Risk_Score': 9.205727693414106},
#  {'datetime': '2024-09-20',
#   'datetimeEpoch': 1726815600.0,
#   'tempmax': 80.5,
#   'tempmin': 59.3,
#   'temp': 67.1,
#   'feelslikemax': 79.6,
#   'feelslikemin': 59.3,
#   'feelslike': 67.0,
#   'dew': 49.8,
#   'humidity': 56.1,
#   'precip': 0.0,
#   'precipprob': 0.0,
#   'precipcover': 0.0,
#   'preciptype': nan,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 9.8,
#   'windspeed': 10.3,
#   'winddir': 278.8,
#   'pressure': 1011.0,
#   'cloudcover': 0.4,
#   'visibility': 14.9,
#   'solarradiation': 237.6,
#   'solarenergy': 20.6,
#   'uvindex': 8.0,
#   'severerisk': 10.0,
#   'sunrise': '06:54:15',
#   'sunriseEpoch': 1726840455.0,
#   'sunset': '19:06:39',
#   'sunsetEpoch': 1726884399.0,
#   'moonphase': 0.59,
#   'conditions': 'Clear',
#   'description': 'Clear conditions throughout the day.',
#   'icon': 'clear-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'San Jose',
#   'Temp_Range': 21.200000000000003,
#   'Heat_Index': 77.05373333982106,
#   'Severity_Score': 2.58,
#   'Condition_Code': 0.0,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Friday',
#   'Is_Weekend': False,
#   'Health_Risk_Score': 9.152753333982108},
#  {'datetime': '2024-09-21',
#   'datetimeEpoch': 1726902000.0,
#   'tempmax': 76.4,
#   'tempmin': 61.4,
#   'temp': 67.4,
#   'feelslikemax': 76.4,
#   'feelslikemin': 61.4,
#   'feelslike': 67.4,
#   'dew': 54.6,
#   'humidity': 64.9,
#   'precip': 0.0,
#   'precipprob': 0.0,
#   'precipcover': 0.0,
#   'preciptype': nan,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 11.2,
#   'windspeed': 10.5,
#   'winddir': 296.3,
#   'pressure': 1012.5,
#   'cloudcover': 59.0,
#   'visibility': 14.9,
#   'solarradiation': 220.3,
#   'solarenergy': 18.9,
#   'uvindex': 8.0,
#   'severerisk': 10.0,
#   'sunrise': '06:55:05',
#   'sunriseEpoch': 1726926905.0,
#   'sunset': '19:05:06',
#   'sunsetEpoch': 1726970706.0,
#   'moonphase': 0.63,
#   'conditions': 'Partially cloudy',
#   'description': 'Partly cloudy throughout the day.',
#   'icon': 'partly-cloudy-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'San Jose',
#   'Temp_Range': 15.000000000000009,
#   'Heat_Index': 75.22822184661618,
#   'Severity_Score': 2.72,
#   'Condition_Code': nan,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Saturday',
#   'Is_Weekend': True,
#   'Health_Risk_Score': 9.288102184661618},
#  {'datetime': '2024-09-07',
#   'datetimeEpoch': 1725685200.0,
#   'tempmax': 92.0,
#   'tempmin': 73.4,
#   'temp': 81.7,
#   'feelslikemax': 90.3,
#   'feelslikemin': 73.4,
#   'feelslike': 81.6,
#   'dew': 60.3,
#   'humidity': 51.1,
#   'precip': 0.0,
#   'precipprob': 1.0,
#   'precipcover': 0.0,
#   'preciptype': nan,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 28.9,
#   'windspeed': 18.3,
#   'winddir': 28.4,
#   'pressure': 1014.5,
#   'cloudcover': 7.3,
#   'visibility': 10.0,
#   'solarradiation': 282.7,
#   'solarenergy': 24.3,
#   'uvindex': 9.0,
#   'severerisk': 10.0,
#   'sunrise': '07:14:53',
#   'sunriseEpoch': 1725711293.0,
#   'sunset': '19:48:16',
#   'sunsetEpoch': 1725756496.0,
#   'moonphase': 0.15,
#   'conditions': 'Clear',
#   'description': 'Clear conditions throughout the day.',
#   'icon': 'clear-day',
#   'stations': "['KSKF', 'KSSF', 'KSAT', 'F6098']",
#   'source': 'comb',
#   'City': 'San Antonio',
#   'Temp_Range': 18.599999999999994,
#   'Heat_Index': 82.6036417074691,
#   'Severity_Score': 4.69,
#   'Condition_Code': 0.0,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Saturday',
#   'Is_Weekend': True,
#   'Health_Risk_Score': 10.656954170746909},
#  {'datetime': '2024-09-08',
#   'datetimeEpoch': 1725771600.0,
#   'tempmax': 87.0,
#   'tempmin': 65.9,
#   'temp': 76.4,
#   'feelslikemax': 84.2,
#   'feelslikemin': 65.9,
#   'feelslike': 75.7,
#   'dew': 50.9,
#   'humidity': 42.5,
#   'precip': 0.0,
#   'precipprob': 0.0,
#   'precipcover': 0.0,
#   'preciptype': nan,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 23.0,
#   'windspeed': 13.9,
#   'winddir': 31.1,
#   'pressure': 1015.8,
#   'cloudcover': 3.6,
#   'visibility': 10.1,
#   'solarradiation': 309.5,
#   'solarenergy': 26.6,
#   'uvindex': 10.0,
#   'severerisk': 10.0,
#   'sunrise': '07:15:25',
#   'sunriseEpoch': 1725797725.0,
#   'sunset': '19:47:04',
#   'sunsetEpoch': 1725842824.0,
#   'moonphase': 0.19,
#   'conditions': 'Clear',
#   'description': 'Clear conditions throughout the day.',
#   'icon': 'clear-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'San Antonio',
#   'Temp_Range': 21.099999999999994,
#   'Heat_Index': 78.07182759970016,
#   'Severity_Score': 4.3,
#   'Condition_Code': 0.0,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Sunday',
#   'Is_Weekend': True,
#   'Health_Risk_Score': 9.634682759970016},
#  {'datetime': '2024-09-09',
#   'datetimeEpoch': 1725858000.0,
#   'tempmax': 88.1,
#   'tempmin': 63.9,
#   'temp': 75.9,
#   'feelslikemax': 85.7,
#   'feelslikemin': 63.9,
#   'feelslike': 75.4,
#   'dew': 52.0,
#   'humidity': 44.5,
#   'precip': 0.0,
#   'precipprob': 5.0,
#   'precipcover': 0.0,
#   'preciptype': nan,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 19.5,
#   'windspeed': 11.4,
#   'winddir': 36.7,
#   'pressure': 1016.8,
#   'cloudcover': 16.4,
#   'visibility': 10.1,
#   'solarradiation': 343.4,
#   'solarenergy': 29.5,
#   'uvindex': 9.0,
#   'severerisk': 10.0,
#   'sunrise': '07:15:56',
#   'sunriseEpoch': 1725884156.0,
#   'sunset': '19:45:51',
#   'sunsetEpoch': 1725929151.0,
#   'moonphase': 0.22,
#   'conditions': 'Clear',
#   'description': 'Clear conditions throughout the day.',
#   'icon': 'clear-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'San Antonio',
#   'Temp_Range': 24.2,
#   'Heat_Index': 77.92671675952508,
#   'Severity_Score': 3.75,
#   'Condition_Code': 0.0,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Monday',
#   'Is_Weekend': False,
#   'Health_Risk_Score': 9.461421675952508},
#  {'datetime': '2024-09-10',
#   'datetimeEpoch': 1725944400.0,
#   'tempmax': 88.8,
#   'tempmin': 70.4,
#   'temp': 79.2,
#   'feelslikemax': 90.5,
#   'feelslikemin': 70.4,
#   'feelslike': 80.0,
#   'dew': 59.4,
#   'humidity': 51.3,
#   'precip': 0.06,
#   'precipprob': 26.0,
#   'precipcover': 20.83,
#   'preciptype': "['rain']",
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 19.5,
#   'windspeed': 10.7,
#   'winddir': 42.2,
#   'pressure': 1013.5,
#   'cloudcover': 38.9,
#   'visibility': 12.1,
#   'solarradiation': 290.4,
#   'solarenergy': 25.0,
#   'uvindex': 9.0,
#   'severerisk': 10.0,
#   'sunrise': '07:16:26',
#   'sunriseEpoch': 1725970586.0,
#   'sunset': '19:44:38',
#   'sunsetEpoch': 1726015478.0,
#   'moonphase': 0.25,
#   'conditions': 'Partially cloudy',
#   'description': 'Partly cloudy throughout the day.',
#   'icon': 'partly-cloudy-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'San Antonio',
#   'Temp_Range': 18.39999999999999,
#   'Heat_Index': 80.225407608356,
#   'Severity_Score': 3.756,
#   'Condition_Code': nan,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Tuesday',
#   'Is_Weekend': False,
#   'Health_Risk_Score': 9.9493687608356},
#  {'datetime': '2024-09-11',
#   'datetimeEpoch': 1726030800.0,
#   'tempmax': 86.6,
#   'tempmin': 74.9,
#   'temp': 80.0,
#   'feelslikemax': 92.7,
#   'feelslikemin': 74.9,
#   'feelslike': 82.4,
#   'dew': 71.0,
#   'humidity': 74.8,
#   'precip': 0.056,
#   'precipprob': 42.0,
#   'precipcover': 16.67,
#   'preciptype': "['rain']",
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 18.3,
#   'windspeed': 10.7,
#   'winddir': 41.2,
#   'pressure': 1008.5,
#   'cloudcover': 51.6,
#   'visibility': 15.0,
#   'solarradiation': 194.4,
#   'solarenergy': 16.7,
#   'uvindex': 5.0,
#   'severerisk': 10.0,
#   'sunrise': '07:16:57',
#   'sunriseEpoch': 1726057017.0,
#   'sunset': '19:43:25',
#   'sunsetEpoch': 1726101805.0,
#   'moonphase': 0.25,
#   'conditions': 'Partially cloudy',
#   'description': 'Partly cloudy throughout the day.',
#   'icon': 'partly-cloudy-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'San Antonio',
#   'Temp_Range': 11.699999999999989,
#   'Heat_Index': 83.54959750320016,
#   'Severity_Score': 2.8356000000000003,
#   'Condition_Code': nan,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Wednesday',
#   'Is_Weekend': False,
#   'Health_Risk_Score': 10.475988550320018},
#  {'datetime': '2024-09-12',
#   'datetimeEpoch': 1726117200.0,
#   'tempmax': 90.1,
#   'tempmin': 73.7,
#   'temp': 81.3,
#   'feelslikemax': 95.2,
#   'feelslikemin': 73.7,
#   'feelslike': 83.8,
#   'dew': 70.2,
#   'humidity': 70.8,
#   'precip': 0.244,
#   'precipprob': 29.0,
#   'precipcover': 16.67,
#   'preciptype': "['rain']",
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 13.9,
#   'windspeed': 7.2,
#   'winddir': 37.7,
#   'pressure': 1007.0,
#   'cloudcover': 28.7,
#   'visibility': 15.0,
#   'solarradiation': 269.3,
#   'solarenergy': 23.1,
#   'uvindex': 9.0,
#   'severerisk': 10.0,
#   'sunrise': '07:17:28',
#   'sunriseEpoch': 1726143448.0,
#   'sunset': '19:42:12',
#   'sunsetEpoch': 1726188132.0,
#   'moonphase': 0.32,
#   'conditions': 'Partially cloudy',
#   'description': 'Partly cloudy throughout the day.',
#   'icon': 'partly-cloudy-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'San Antonio',
#   'Temp_Range': 16.39999999999999,
#   'Heat_Index': 85.30163519543603,
#   'Severity_Score': 3.2144000000000004,
#   'Condition_Code': nan,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Thursday',
#   'Is_Weekend': False,
#   'Health_Risk_Score': 10.805958719543604},
#  {'datetime': '2024-09-13',
#   'datetimeEpoch': 1726203600.0,
#   'tempmax': 92.6,
#   'tempmin': 75.5,
#   'temp': 83.3,
#   'feelslikemax': 98.3,
#   'feelslikemin': 75.5,
#   'feelslike': 86.7,
#   'dew': 71.1,
#   'humidity': 68.3,
#   'precip': 0.02,
#   'precipprob': 23.0,
#   'precipcover': 8.33,
#   'preciptype': "['rain']",
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 12.5,
#   'windspeed': 7.2,
#   'winddir': 124.3,
#   'pressure': 1009.8,
#   'cloudcover': 33.5,
#   'visibility': 15.0,
#   'solarradiation': 262.6,
#   'solarenergy': 22.6,
#   'uvindex': 9.0,
#   'severerisk': 10.0,
#   'sunrise': '07:17:59',
#   'sunriseEpoch': 1726229879.0,
#   'sunset': '19:40:58',
#   'sunsetEpoch': 1726274458.0,
#   'moonphase': 0.35,
#   'conditions': 'Partially cloudy',
#   'description': 'Partly cloudy throughout the day.',
#   'icon': 'partly-cloudy-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'San Antonio',
#   'Temp_Range': 17.099999999999994,
#   'Heat_Index': 88.52007848634103,
#   'Severity_Score': 3.052,
#   'Condition_Code': nan,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Friday',
#   'Is_Weekend': False,
#   'Health_Risk_Score': 10.936523848634105},
#  {'datetime': '2024-09-14',
#   'datetimeEpoch': 1726290000.0,
#   'tempmax': 92.9,
#   'tempmin': 76.7,
#   'temp': 84.4,
#   'feelslikemax': 99.9,
#   'feelslikemin': 76.7,
#   'feelslike': 89.1,
#   'dew': 72.6,
#   'humidity': 69.1,
#   'precip': 0.063,
#   'precipprob': 30.0,
#   'precipcover': 12.5,
#   'preciptype': "['rain']",
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 13.2,
#   'windspeed': 8.1,
#   'winddir': 132.5,
#   'pressure': 1011.0,
#   'cloudcover': 44.1,
#   'visibility': 15.0,
#   'solarradiation': 265.3,
#   'solarenergy': 22.8,
#   'uvindex': 8.0,
#   'severerisk': 10.0,
#   'sunrise': '07:18:30',
#   'sunriseEpoch': 1726316310.0,
#   'sunset': '19:39:45',
#   'sunsetEpoch': 1726360785.0,
#   'moonphase': 0.39,
#   'conditions': 'Partially cloudy',
#   'description': 'Partly cloudy throughout the day.',
#   'icon': 'partly-cloudy-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'San Antonio',
#   'Temp_Range': 16.200000000000003,
#   'Heat_Index': 91.04123081523592,
#   'Severity_Score': 2.9263,
#   'Condition_Code': nan,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Saturday',
#   'Is_Weekend': True,
#   'Health_Risk_Score': 11.126196381523592},
#  {'datetime': '2024-09-15',
#   'datetimeEpoch': 1726376400.0,
#   'tempmax': 98.3,
#   'tempmin': 77.4,
#   'temp': 86.6,
#   'feelslikemax': 99.5,
#   'feelslikemin': 77.4,
#   'feelslike': 88.1,
#   'dew': 66.6,
#   'humidity': 54.8,
#   'precip': 0.004,
#   'precipprob': 29.0,
#   'precipcover': 4.17,
#   'preciptype': "['rain']",
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 21.0,
#   'windspeed': 12.3,
#   'winddir': 145.8,
#   'pressure': 1011.4,
#   'cloudcover': 29.2,
#   'visibility': 15.0,
#   'solarradiation': 274.7,
#   'solarenergy': 23.6,
#   'uvindex': 8.0,
#   'severerisk': 10.0,
#   'sunrise': '07:19:01',
#   'sunriseEpoch': 1726402741.0,
#   'sunset': '19:38:31',
#   'sunsetEpoch': 1726447111.0,
#   'moonphase': 0.42,
#   'conditions': 'Partially cloudy',
#   'description': 'Partly cloudy throughout the day.',
#   'icon': 'partly-cloudy-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'San Antonio',
#   'Temp_Range': 20.89999999999999,
#   'Heat_Index': 90.356070721024,
#   'Severity_Score': 3.7004,
#   'Condition_Code': nan,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Sunday',
#   'Is_Weekend': True,
#   'Health_Risk_Score': 11.0634262721024},
#  {'datetime': '2024-09-16',
#   'datetimeEpoch': 1726462800.0,
#   'tempmax': 95.8,
#   'tempmin': 75.6,
#   'temp': 84.8,
#   'feelslikemax': 95.6,
#   'feelslikemin': 75.6,
#   'feelslike': 85.6,
#   'dew': 64.6,
#   'humidity': 53.4,
#   'precip': 0.142,
#   'precipprob': 22.6,
#   'precipcover': 8.33,
#   'preciptype': "['rain']",
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 22.1,
#   'windspeed': 11.9,
#   'winddir': 147.7,
#   'pressure': 1011.9,
#   'cloudcover': 46.0,
#   'visibility': 15.0,
#   'solarradiation': 268.4,
#   'solarenergy': 23.3,
#   'uvindex': 8.0,
#   'severerisk': 10.0,
#   'sunrise': '07:19:32',
#   'sunriseEpoch': 1726489172.0,
#   'sunset': '19:37:17',
#   'sunsetEpoch': 1726533437.0,
#   'moonphase': 0.45,
#   'conditions': 'Partially cloudy',
#   'description': 'Becoming cloudy in the afternoon.',
#   'icon': 'partly-cloudy-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'San Antonio',
#   'Temp_Range': 20.200000000000003,
#   'Heat_Index': 87.03550035462392,
#   'Severity_Score': 3.8242,
#   'Condition_Code': nan,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Monday',
#   'Is_Weekend': False,
#   'Health_Risk_Score': 10.745672835462392},
#  {'datetime': '2024-09-17',
#   'datetimeEpoch': 1726549200.0,
#   'tempmax': 94.2,
#   'tempmin': 74.6,
#   'temp': 83.3,
#   'feelslikemax': 92.9,
#   'feelslikemin': 74.6,
#   'feelslike': 83.8,
#   'dew': 64.9,
#   'humidity': 57.1,
#   'precip': 0.0,
#   'precipprob': 22.6,
#   'precipcover': 0.0,
#   'preciptype': nan,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 20.1,
#   'windspeed': 15.4,
#   'winddir': 127.7,
#   'pressure': 1011.9,
#   'cloudcover': 39.9,
#   'visibility': 15.0,
#   'solarradiation': 275.1,
#   'solarenergy': 23.7,
#   'uvindex': 8.0,
#   'severerisk': 10.0,
#   'sunrise': '07:20:03',
#   'sunriseEpoch': 1726575603.0,
#   'sunset': '19:36:03',
#   'sunsetEpoch': 1726619763.0,
#   'moonphase': 0.5,
#   'conditions': 'Partially cloudy',
#   'description': 'Clearing in the afternoon.',
#   'icon': 'partly-cloudy-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'San Antonio',
#   'Temp_Range': 19.60000000000001,
#   'Heat_Index': 85.71944942646917,
#   'Severity_Score': 3.61,
#   'Condition_Code': nan,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Tuesday',
#   'Is_Weekend': False,
#   'Health_Risk_Score': 10.633254942646918},
#  {'datetime': '2024-09-18',
#   'datetimeEpoch': 1726635600.0,
#   'tempmax': 95.1,
#   'tempmin': 72.9,
#   'temp': 82.6,
#   'feelslikemax': 94.4,
#   'feelslikemin': 72.9,
#   'feelslike': 83.4,
#   'dew': 66.6,
#   'humidity': 62.4,
#   'precip': 0.0,
#   'precipprob': 16.1,
#   'precipcover': 0.0,
#   'preciptype': nan,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 19.5,
#   'windspeed': 15.7,
#   'winddir': 127.1,
#   'pressure': 1012.3,
#   'cloudcover': 19.0,
#   'visibility': 15.0,
#   'solarradiation': 269.0,
#   'solarenergy': 23.2,
#   'uvindex': 8.0,
#   'severerisk': 10.0,
#   'sunrise': '07:20:35',
#   'sunriseEpoch': 1726662035.0,
#   'sunset': '19:34:49',
#   'sunsetEpoch': 1726706089.0,
#   'moonphase': 0.52,
#   'conditions': 'Clear',
#   'description': 'Clear conditions throughout the day.',
#   'icon': 'clear-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'San Antonio',
#   'Temp_Range': 22.19999999999999,
#   'Heat_Index': 85.81762362425592,
#   'Severity_Score': 3.55,
#   'Condition_Code': 0.0,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Wednesday',
#   'Is_Weekend': False,
#   'Health_Risk_Score': 10.79696236242559},
#  {'datetime': '2024-09-19',
#   'datetimeEpoch': 1726722000.0,
#   'tempmax': 94.9,
#   'tempmin': 73.5,
#   'temp': 82.7,
#   'feelslikemax': 95.8,
#   'feelslikemin': 73.5,
#   'feelslike': 84.3,
#   'dew': 68.3,
#   'humidity': 65.0,
#   'precip': 0.004,
#   'precipprob': 9.7,
#   'precipcover': 4.17,
#   'preciptype': "['rain']",
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 19.5,
#   'windspeed': 9.8,
#   'winddir': 125.4,
#   'pressure': 1012.3,
#   'cloudcover': 63.2,
#   'visibility': 14.6,
#   'solarradiation': 233.9,
#   'solarenergy': 20.1,
#   'uvindex': 7.0,
#   'severerisk': 30.0,
#   'sunrise': '07:21:06',
#   'sunriseEpoch': 1726748466.0,
#   'sunset': '19:33:35',
#   'sunsetEpoch': 1726792415.0,
#   'moonphase': 0.55,
#   'conditions': 'Partially cloudy',
#   'description': 'Partly cloudy throughout the day.',
#   'icon': 'partly-cloudy-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'San Antonio',
#   'Temp_Range': 21.40000000000001,
#   'Heat_Index': 86.5697013268,
#   'Severity_Score': 3.3504,
#   'Condition_Code': nan,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Thursday',
#   'Is_Weekend': False,
#   'Health_Risk_Score': 10.83473013268},
#  {'datetime': '2024-09-20',
#   'datetimeEpoch': 1726808400.0,
#   'tempmax': 96.3,
#   'tempmin': 74.2,
#   'temp': 83.9,
#   'feelslikemax': 97.3,
#   'feelslikemin': 74.2,
#   'feelslike': 85.2,
#   'dew': 67.8,
#   'humidity': 62.0,
#   'precip': 0.024,
#   'precipprob': 16.1,
# ...
#   'Condition_Code': nan,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Friday',
#   'Is_Weekend': False,
#   'Health_Risk_Score': 11.08840484800422},
#  {'datetime': '2024-09-21',
#   'datetimeEpoch': 1726914197.4601583,
#   'tempmax': 95.69575155876342,
#   'tempmin': 83.28814939210298,
#   'temp': 90.23872422325957,
#   'feelslikemax': 95.9674724596664,
#   'feelslikemin': 82.91394419448211,
#   'feelslike': 89.46353303885307,
#   'dew': 62.85232578579062,
#   'humidity': 39.5421001259902,
#   'precip': 0.0034683796788736,
#   'precipprob': 23.11820792339686,
#   'precipcover': 0.5827647318238625,
#   'preciptype': nan,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 22.55345080213168,
#   'windspeed': 10.801734397837697,
#   'winddir': 161.82346666228335,
#   'pressure': 1013.7409043116176,
#   'cloudcover': 39.35108482119317,
#   'visibility': 14.935955465715235,
#   'solarradiation': 194.02164738051428,
#   'solarenergy': 16.190113881605146,
#   'uvindex': 6.947536329481274,
#   'severerisk': 29.393800593502213,
#   'sunrise': '07:15:05',
#   'sunriseEpoch': 1726909770.745688,
#   'sunset': '19:24:32',
#   'sunsetEpoch': 1726920835.2464256,
#   'moonphase': 0.6034672157788186,
#   'conditions': 'Partially cloudy',
#   'description': 'Becoming cloudy in the afternoon.',
#   'icon': 'partly-cloudy-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'Dallas',
#   'Temp_Range': 13.451165580353075,
#   'Heat_Index': 88.86322182138562,
#   'Severity_Score': 3.573576927661866,
#   'Condition_Code': nan,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Saturday',
#   'Is_Weekend': True,
#   'Health_Risk_Score': 10.596044079082452},
#  {'datetime': '2024-09-13',
#   'datetimeEpoch': 1726175486.2362654,
#   'tempmax': 101.88904675921944,
#   'tempmin': 78.49198341717316,
#   'temp': 87.95377309701126,
#   'feelslikemax': 99.64400543262664,
#   'feelslikemin': 77.61099756031531,
#   'feelslike': 85.65140045746418,
#   'dew': 43.27638633874942,
#   'humidity': 19.78834458609204,
#   'precip': 0.0069298283664787,
#   'precipprob': 1.98769763516644,
#   'precipcover': -0.2482574004316305,
#   'preciptype': nan,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 13.635669574391224,
#   'windspeed': 6.988953505614243,
#   'winddir': 200.84959661654452,
#   'pressure': 1006.6920306270868,
#   'cloudcover': 6.721897842320516,
#   'visibility': 14.905528625926854,
#   'solarradiation': 262.74259760027206,
#   'solarenergy': 23.2108183951274,
#   'uvindex': 8.979890740727404,
#   'severerisk': 9.774333547162309,
#   'sunrise': '06:10:49',
#   'sunriseEpoch': 1726252823.8175352,
#   'sunset': '18:36:41',
#   'sunsetEpoch': 1726244605.885675,
#   'moonphase': 0.3652459170038005,
#   'conditions': 'Clear',
#   'description': 'Clear conditions throughout the day.',
#   'icon': 'clear-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'Phoenix',
#   'Temp_Range': 23.100771296999483,
#   'Heat_Index': 84.65618566679967,
#   'Severity_Score': 3.2707472988402,
#   'Condition_Code': 0.0,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Friday',
#   'Is_Weekend': False,
#   'Health_Risk_Score': 9.24045192685017},
#  {'datetime': '2024-09-08',
#   'datetimeEpoch': 1725708405.2121773,
#   'tempmax': 71.79969362969263,
#   'tempmin': 53.65298802966806,
#   'temp': 61.51755067045899,
#   'feelslikemax': 71.03572519979996,
#   'feelslikemin': 55.17798890081461,
#   'feelslike': 62.2295961156849,
#   'dew': 45.39421216951333,
#   'humidity': 57.06527328381332,
#   'precip': -0.0101554152889208,
#   'precipprob': -0.5091406964942689,
#   'precipcover': -0.4839132961891843,
#   'preciptype': nan,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 20.539267271738563,
#   'windspeed': 12.969655294318189,
#   'winddir': 298.24130171019056,
#   'pressure': 1016.1561013536312,
#   'cloudcover': 5.436454817105747,
#   'visibility': 10.091337412196918,
#   'solarradiation': 277.17053671359315,
#   'solarenergy': 23.69997699230058,
#   'uvindex': 8.193348583014963,
#   'severerisk': 10.681134674079896,
#   'sunrise': '06:30:22',
#   'sunriseEpoch': 1725762078.995839,
#   'sunset': '19:16:00',
#   'sunsetEpoch': 1725825603.5741415,
#   'moonphase': 0.1832224718180167,
#   'conditions': 'Clear',
#   'description': 'Clear conditions throughout the day.',
#   'icon': 'clear-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'New York City',
#   'Temp_Range': 17.31468054576304,
#   'Heat_Index': 81.25258557168682,
#   'Severity_Score': 3.590244528599281,
#   'Condition_Code': 0.0,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Sunday',
#   'Is_Weekend': True,
#   'Health_Risk_Score': 9.992650842897769},
#  {'datetime': '2024-09-14',
#   'datetimeEpoch': 1726324339.9349942,
#   'tempmax': 81.74612209280176,
#   'tempmin': 57.92061165126442,
#   'temp': 68.28973426709034,
#   'feelslikemax': 81.70591185683595,
#   'feelslikemin': 59.05264289787935,
#   'feelslike': 68.08103954629507,
#   'dew': 55.53434853960855,
#   'humidity': 65.83366751383659,
#   'precip': -0.0061385620042308,
#   'precipprob': 1.6205090644009694,
#   'precipcover': 0.4908390741293414,
#   'preciptype': nan,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 16.153804998329132,
#   'windspeed': 9.802508660671766,
#   'winddir': 262.7384175470823,
#   'pressure': 1010.439757068691,
#   'cloudcover': 7.98739781948177,
#   'visibility': 15.070648532744952,
#   'solarradiation': 267.7554466649405,
#   'solarenergy': 22.9155191176557,
#   'uvindex': 8.008525784925224,
#   'severerisk': 10.159579573002018,
#   'sunrise': '06:49:17',
#   'sunriseEpoch': 1726303722.6126804,
#   'sunset': '19:15:53',
#   'sunsetEpoch': 1726376300.5104585,
#   'moonphase': 0.3861693636508468,
#   'conditions': 'Clear',
#   'description': 'Clear conditions throughout the day.',
#   'icon': 'clear-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'San Jose',
#   'Temp_Range': 22.078094557169205,
#   'Heat_Index': 75.57252819580282,
#   'Severity_Score': 3.33735540246771,
#   'Condition_Code': 0.0,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Saturday',
#   'Is_Weekend': True,
#   'Health_Risk_Score': 9.672304219710371},
#  {'datetime': '2024-09-21',
#   'datetimeEpoch': 1726878269.714957,
#   'tempmax': 83.47610093475241,
#   'tempmin': 70.29965070708151,
#   'temp': 74.7694522765621,
#   'feelslikemax': 83.68241325827412,
#   'feelslikemin': 70.9265262527191,
#   'feelslike': 75.64138437807411,
#   'dew': 59.36360250250752,
#   'humidity': 56.26561829168596,
#   'precip': 0.4527229667463913,
#   'precipprob': 13.934624335155489,
#   'precipcover': 4.668726240187659,
#   'preciptype': "['rain']",
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 11.88232049500907,
#   'windspeed': 9.962767214612107,
#   'winddir': 107.79407975920785,
#   'pressure': 1018.6851075945244,
#   'cloudcover': 34.14960805031401,
#   'visibility': 14.94585625198865,
#   'solarradiation': 223.3052999259675,
#   'solarenergy': 18.418863682229432,
#   'uvindex': 6.733374960132702,
#   'severerisk': 10.264639777147517,
#   'sunrise': '06:43:05',
#   'sunriseEpoch': 1726886986.3047202,
#   'sunset': '18:54:06',
#   'sunsetEpoch': 1726966788.9209592,
#   'moonphase': 0.6294364778153209,
#   'conditions': 'Partially cloudy',
#   'description': 'Becoming cloudy in the afternoon.',
#   'icon': 'partly-cloudy-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'New York City',
#   'Temp_Range': 12.084129933029036,
#   'Heat_Index': 78.69328608858227,
#   'Severity_Score': 2.7413313203575047,
#   'Condition_Code': nan,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Saturday',
#   'Is_Weekend': True,
#   'Health_Risk_Score': 9.195290006912863},
#  {'datetime': '2024-09-09',
#   'datetimeEpoch': 1725888520.0946374,
#   'tempmax': 89.34449319045162,
#   'tempmin': 62.68428416826358,
#   'temp': 72.01311908458757,
#   'feelslikemax': 87.70291211042257,
#   'feelslikemin': 63.345555229978295,
#   'feelslike': 73.34544054676196,
#   'dew': 56.88078006023866,
#   'humidity': 60.31027992997962,
#   'precip': 0.010856775910514,
#   'precipprob': 1.0414202945889954,
#   'precipcover': -0.3609074448676077,
#   'preciptype': nan,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 16.754453339743343,
#   'windspeed': 9.23842214597712,
#   'winddir': 312.7965196890869,
#   'pressure': 1013.2411834772188,
#   'cloudcover': 12.53409438683624,
#   'visibility': 10.27437042043096,
#   'solarradiation': 306.14868872619405,
#   'solarenergy': 28.21200230945476,
#   'uvindex': 9.226183408926858,
#   'severerisk': 10.685192564909247,
#   'sunrise': '06:45:10',
#   'sunriseEpoch': 1725921250.039528,
#   'sunset': '19:23:32',
#   'sunsetEpoch': 1726031479.2410667,
#   'moonphase': 0.2060399721972967,
#   'conditions': 'Clear',
#   'description': 'Clear conditions throughout the day.',
#   'icon': 'clear-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'San Jose',
#   'Temp_Range': 24.51420315518869,
#   'Heat_Index': 77.3494022159497,
#   'Severity_Score': 3.4083730471155165,
#   'Condition_Code': 0.0,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Monday',
#   'Is_Weekend': False,
#   'Health_Risk_Score': 9.615947756578054},
#  {'datetime': '2024-09-18',
#   'datetimeEpoch': 1726632591.6908827,
#   'tempmax': 76.06054558382108,
#   'tempmin': 64.35938718112125,
#   'temp': 69.0021418646212,
#   'feelslikemax': 77.67382309684628,
#   'feelslikemin': 63.51092001820757,
#   'feelslike': 67.00333838737069,
#   'dew': 59.93677637799703,
#   'humidity': 73.18912995767292,
#   'precip': 0.0846599550485508,
#   'precipprob': 30.567090880517146,
#   'precipcover': 3.481762742020263,
#   'preciptype': "['rain']",
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 13.864631630856165,
#   'windspeed': 7.435891471784491,
#   'winddir': 51.161203277087125,
#   'pressure': 1023.2844766459611,
#   'cloudcover': 80.51276945221578,
#   'visibility': 14.696975809263373,
#   'solarradiation': 71.4583316047323,
#   'solarenergy': 6.994928144854293,
#   'uvindex': 3.121167366667473,
#   'severerisk': 10.563083569398849,
#   'sunrise': '06:44:57',
#   'sunriseEpoch': 1726690767.5344625,
#   'sunset': '19:03:37',
#   'sunsetEpoch': 1726616079.1568072,
#   'moonphase': 0.520096053095155,
#   'conditions': 'Partially cloudy',
#   'description': 'Partly cloudy throughout the day.',
#   'icon': 'partly-cloudy-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'Philadelphia',
#   'Temp_Range': 12.88666476515724,
#   'Heat_Index': 71.83755780601577,
#   'Severity_Score': 1.9573182494350945,
#   'Condition_Code': nan,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Wednesday',
#   'Is_Weekend': False,
#   'Health_Risk_Score': 8.75014194400079},
#  {'datetime': '2024-09-17',
#   'datetimeEpoch': 1726550178.2591555,
#   'tempmax': 68.40919805738676,
#   'tempmin': 65.93931890816431,
#   'temp': 66.5674095722523,
#   'feelslikemax': 68.95672182923013,
#   'feelslikemin': 64.80563549957625,
#   'feelslike': 65.9925263191593,
#   'dew': 59.0102568080488,
#   'humidity': 74.13740133415534,
#   'precip': 0.0198467112477763,
#   'precipprob': 6.993677387681553,
#   'precipcover': 4.239993829695987,
#   'preciptype': "['rain']",
#   'snow': 0.0,
#   'snowdepth': nan,
#   'windgust': 6.233441261907524,
#   'windspeed': 8.930235260928479,
#   'winddir': 274.833365168613,
#   'pressure': 1010.5125034170854,
#   'cloudcover': 14.85261051809186,
#   'visibility': 15.09266253541919,
#   'solarradiation': 282.75128284580086,
#   'solarenergy': 22.61997936730386,
#   'uvindex': 8.919897091467478,
#   'severerisk': 9.83876673330125,
#   'sunrise': '06:34:01',
#   'sunriseEpoch': 1726593864.3125677,
#   'sunset': '18:51:20',
#   'sunsetEpoch': 1726665823.1481676,
#   'moonphase': 0.4775565382490627,
#   'conditions': 'Clear',
#   'description': 'Clear conditions throughout the day.',
#   'icon': 'clear-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'San Diego',
#   'Temp_Range': 2.613629381455857,
#   'Heat_Index': 72.46349128664832,
#   'Severity_Score': 2.537412696095077,
#   'Condition_Code': 0.0,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Tuesday',
#   'Is_Weekend': False,
#   'Health_Risk_Score': 9.118198210752777},
#  {'datetime': '2024-09-12',
#   'datetimeEpoch': 1726121997.6822324,
#   'tempmax': 69.75669024854497,
#   'tempmin': 65.28691862054913,
#   'temp': 65.91949220060405,
#   'feelslikemax': 68.15853607683025,
#   'feelslikemin': 63.6629423965658,
#   'feelslike': 67.31332240561775,
#   'dew': 62.02444216027467,
#   'humidity': 84.65048171126641,
#   'precip': -0.0101325022253698,
#   'precipprob': 7.67251858935306,
#   'precipcover': 0.024862696942279,
#   'preciptype': nan,
#   'snow': 0.0,
#   'snowdepth': nan,
#   'windgust': 17.387860392348312,
#   'windspeed': 11.082902910157276,
#   'winddir': 196.36169150648317,
#   'pressure': 1005.594740059596,
#   'cloudcover': 46.72186089578294,
#   'visibility': 14.909931114159278,
#   'solarradiation': 272.04369261052057,
#   'solarenergy': 23.83047902789889,
#   'uvindex': 9.0895467762213,
#   'severerisk': 10.502440307302235,
#   'sunrise': '06:30:49',
#   'sunriseEpoch': 1726118777.4287124,
#   'sunset': '18:58:05',
#   'sunsetEpoch': 1726232300.5494423,
#   'moonphase': 0.3183385379385459,
#   'conditions': 'Partially cloudy',
#   'description': 'Partly cloudy throughout the day.',
#   'icon': 'partly-cloudy-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'San Diego',
#   'Temp_Range': 4.598936354061397,
#   'Heat_Index': 67.56005962410542,
#   'Severity_Score': 3.5954702517882238,
#   'Condition_Code': nan,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Thursday',
#   'Is_Weekend': False,
#   'Health_Risk_Score': 9.880093305614066},
#  {'datetime': '2024-09-14',
#   'datetimeEpoch': 1726283773.8442173,
#   'tempmax': 77.10679745520832,
#   'tempmin': 61.481724263434025,
#   'temp': 68.10656881947024,
#   'feelslikemax': 76.42695863320282,
#   'feelslikemin': 60.90152579218709,
#   'feelslike': 68.09430850933552,
#   'dew': 63.16960756488583,
#   'humidity': 86.86026071244493,
#   'precip': -0.0024396636720878,
#   'precipprob': 0.9869657693201868,
#   'precipcover': 0.1328250207518287,
#   'preciptype': nan,
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 15.74827031797913,
#   'windspeed': 8.028199990157285,
#   'winddir': 219.7399694549943,
#   'pressure': 1011.2300549301156,
#   'cloudcover': 12.583792993505975,
#   'visibility': 15.052398883218446,
#   'solarradiation': 271.0068845579768,
#   'solarenergy': 22.746817873697367,
#   'uvindex': 8.908550146656278,
#   'severerisk': 9.847928794782884,
#   'sunrise': '06:35:57',
#   'sunriseEpoch': 1726296562.7305048,
#   'sunset': '19:00:10',
#   'sunsetEpoch': 1726331361.0254638,
#   'moonphase': 0.3973036842307673,
#   'conditions': 'Clear',
#   'description': 'Clear conditions throughout the day.',
#   'icon': 'clear-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'Los Angeles',
#   'Temp_Range': 15.477717326555805,
#   'Heat_Index': 67.93043708900912,
#   'Severity_Score': 3.4989422443113094,
#   'Condition_Code': 0.0,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Saturday',
#   'Is_Weekend': True,
#   'Health_Risk_Score': 9.561602091400758},
#  {'datetime': '2024-09-18',
#   'datetimeEpoch': 1726618424.5460238,
#   'tempmax': 90.92308027793686,
#   'tempmin': 79.29686763922918,
#   'temp': 81.63699076338789,
#   'feelslikemax': 94.1804225681944,
#   'feelslikemin': 78.07185101153438,
#   'feelslike': 84.9871129145816,
#   'dew': 73.39304500862426,
#   'humidity': 74.73471494689899,
#   'precip': 0.1516152579003476,
#   'precipprob': 32.11207042760594,
#   'precipcover': 4.673089669257601,
#   'preciptype': "['rain']",
#   'snow': 0.0,
#   'snowdepth': 0.0,
#   'windgust': 16.61535124387185,
#   'windspeed': 10.479637352198475,
#   'winddir': 104.04335705954816,
#   'pressure': 1012.5075974684952,
#   'cloudcover': 17.31376302108133,
#   'visibility': 15.178379396903722,
#   'solarradiation': 245.190433291764,
#   'solarenergy': 20.8396895205759,
#   'uvindex': 6.904596917251116,
#   'severerisk': 30.395643042870027,
#   'sunrise': '07:08:01',
#   'sunriseEpoch': 1726634978.5487976,
#   'sunset': '19:22:23',
#   'sunsetEpoch': 1726687669.515567,
#   'moonphase': 0.5316302475058464,
#   'conditions': 'Clear',
#   'description': 'Clear conditions throughout the day with storms possible.',
#   'icon': 'clear-day',
#   'stations': nan,
#   'source': 'fcst',
#   'City': 'Houston',
#   'Temp_Range': 11.01787051517568,
#   'Heat_Index': 86.80271244158527,
#   'Severity_Score': 3.0400203047352656,
#   'Condition_Code': 0.0,
#   'Month': 9.0,
#   'Season': 'Fall',
#   'Day_of_Week': 'Wednesday',
#   'Is_Weekend': False,
#   'Health_Risk_Score': 10.97804447087361}]

# %%
len(data)
# Out:
# 1000

# %%
DB_NAME = "UAHI"
COLLECTION_NAME = "urban_air_impact"
CONNECTION_URL = "mongodb+srv://srsingh2678:srsingh2678@cluster0.eaaga.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
import pymongo

# %%
client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]

rec = collection.insert_many(data)

# %%
records = collection.find()
records

# %%
for i, j in enumerate(records):
    print(f"{i}: {j}")
# Out:
# 0: {'_id': ObjectId('67082952b0379fdf34f00c37'), 'datetime': '2024-09-07', 'datetimeEpoch': 1725692400.0, 'tempmax': 106.1, 'tempmin': 91.0, 'temp': 98.5, 'feelslikemax': 104.0, 'feelslikemin': 88.1, 'feelslike': 95.9, 'dew': 51.5, 'humidity': 21.0, 'precip': 0.0, 'precipprob': 5.0, 'precipcover': 0.0, 'preciptype': nan, 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 26.3, 'windspeed': 13.7, 'winddir': 107.3, 'pressure': 1009.2, 'cloudcover': 25.0, 'visibility': 10.0, 'solarradiation': 261.4, 'solarenergy': 22.5, 'uvindex': 9.0, 'severerisk': 10.0, 'sunrise': '06:06:50', 'sunriseEpoch': 1725714410.0, 'sunset': '18:44:53', 'sunsetEpoch': 1725759893.0, 'moonphase': 0.16, 'conditions': 'Partially cloudy', 'description': 'Partly cloudy throughout the day.', 'icon': 'partly-cloudy-day', 'stations': "['KSDL', 'KDVT', 'AZM15', 'KPHX']", 'source': 'comb', 'City': 'Phoenix', 'Temp_Range': 15.099999999999994, 'Heat_Index': 95.91870310999995, 'Severity_Score': 4.43, 'Condition_Code': nan, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Saturday', 'Is_Weekend': True, 'Health_Risk_Score': 10.522170310999996}
# 1: {'_id': ObjectId('67082952b0379fdf34f00c38'), 'datetime': '2024-09-08', 'datetimeEpoch': 1725778800.0, 'tempmax': 103.9, 'tempmin': 87.0, 'temp': 95.4, 'feelslikemax': 100.5, 'feelslikemin': 84.7, 'feelslike': 92.3, 'dew': 48.7, 'humidity': 21.5, 'precip': 0.0, 'precipprob': 3.0, 'precipcover': 0.0, 'preciptype': nan, 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 20.8, 'windspeed': 12.8, 'winddir': 101.5, 'pressure': 1008.8, 'cloudcover': 13.5, 'visibility': 10.1, 'solarradiation': 293.3, 'solarenergy': 25.2, 'uvindex': 9.0, 'severerisk': 10.0, 'sunrise': '06:07:30', 'sunriseEpoch': 1725800850.0, 'sunset': '18:43:32', 'sunsetEpoch': 1725846212.0, 'moonphase': 0.19, 'conditions': 'Clear', 'description': 'Clear conditions throughout the day.', 'icon': 'clear-day', 'stations': nan, 'source': 'fcst', 'City': 'Phoenix', 'Temp_Range': 16.900000000000006, 'Heat_Index': 92.28131624140006, 'Severity_Score': 3.88, 'Condition_Code': 0.0, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Sunday', 'Is_Weekend': True, 'Health_Risk_Score': 10.062331624140006}
# 2: {'_id': ObjectId('67082952b0379fdf34f00c39'), 'datetime': '2024-09-09', 'datetimeEpoch': 1725865200.0, 'tempmax': 105.0, 'tempmin': 83.9, 'temp': 94.7, 'feelslikemax': 99.9, 'feelslikemin': 81.6, 'feelslike': 90.6, 'dew': 41.7, 'humidity': 16.9, 'precip': 0.0, 'precipprob': 0.0, 'precipcover': 0.0, 'preciptype': nan, 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 18.3, 'windspeed': 10.3, 'winddir': 90.8, 'pressure': 1009.4, 'cloudcover': 6.2, 'visibility': 10.1, 'solarradiation': 327.0, 'solarenergy': 28.2, 'uvindex': 9.0, 'severerisk': 10.0, 'sunrise': '06:08:10', 'sunriseEpoch': 1725887290.0, 'sunset': '18:42:10', 'sunsetEpoch': 1725932530.0, 'moonphase': 0.22, 'conditions': 'Clear', 'description': 'Clear conditions throughout the day.', 'icon': 'clear-day', 'stations': nan, 'source': 'fcst', 'City': 'Phoenix', 'Temp_Range': 21.099999999999994, 'Heat_Index': 90.5991651058291, 'Severity_Score': 3.63, 'Condition_Code': 0.0, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Monday', 'Is_Weekend': False, 'Health_Risk_Score': 9.67338651058291}
# 3: {'_id': ObjectId('67082952b0379fdf34f00c3a'), 'datetime': '2024-09-10', 'datetimeEpoch': 1725951600.0, 'tempmax': 106.1, 'tempmin': 81.2, 'temp': 93.9, 'feelslikemax': 100.6, 'feelslikemin': 79.5, 'feelslike': 89.8, 'dew': 39.1, 'humidity': 15.7, 'precip': 0.012, 'precipprob': 0.0, 'precipcover': 4.17, 'preciptype': "['rain']", 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 10.5, 'windspeed': 5.4, 'winddir': 130.1, 'pressure': 1006.8, 'cloudcover': 4.9, 'visibility': 12.5, 'solarradiation': 276.8, 'solarenergy': 24.0, 'uvindex': 9.0, 'severerisk': 10.0, 'sunrise': '06:08:49', 'sunriseEpoch': 1725973729.0, 'sunset': '18:40:48', 'sunsetEpoch': 1726018848.0, 'moonphase': 0.25, 'conditions': 'Clear', 'description': 'Clear conditions throughout the day.', 'icon': 'clear-day', 'stations': nan, 'source': 'fcst', 'City': 'Phoenix', 'Temp_Range': 24.89999999999999, 'Heat_Index': 89.6388106900291, 'Severity_Score': 2.8512000000000004, 'Condition_Code': 0.0, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Tuesday', 'Is_Weekend': False, 'Health_Risk_Score': 9.411519469002911}
# 4: {'_id': ObjectId('67082952b0379fdf34f00c3b'), 'datetime': '2024-09-11', 'datetimeEpoch': 1726038000.0, 'tempmax': 106.1, 'tempmin': 82.1, 'temp': 94.0, 'feelslikemax': 101.0, 'feelslikemin': 80.0, 'feelslike': 90.0, 'dew': 40.1, 'humidity': 15.9, 'precip': 0.008, 'precipprob': 0.0, 'precipcover': 4.17, 'preciptype': "['rain']", 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 15.9, 'windspeed': 8.1, 'winddir': 201.6, 'pressure': 1001.8, 'cloudcover': 5.7, 'visibility': 15.0, 'solarradiation': 274.9, 'solarenergy': 23.7, 'uvindex': 9.0, 'severerisk': 10.0, 'sunrise': '06:09:29', 'sunriseEpoch': 1726060169.0, 'sunset': '18:39:26', 'sunsetEpoch': 1726105166.0, 'moonphase': 0.29, 'conditions': 'Clear', 'description': 'Clear conditions throughout the day.', 'icon': 'clear-day', 'stations': nan, 'source': 'fcst', 'City': 'Phoenix', 'Temp_Range': 24.0, 'Heat_Index': 89.76041382170003, 'Severity_Score': 3.3908, 'Condition_Code': 0.0, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Wednesday', 'Is_Weekend': False, 'Health_Risk_Score': 9.515178582170003}
# 5: {'_id': ObjectId('67082952b0379fdf34f00c3c'), 'datetime': '2024-09-12', 'datetimeEpoch': 1726124400.0, 'tempmax': 103.0, 'tempmin': 81.6, 'temp': 91.5, 'feelslikemax': 98.1, 'feelslikemin': 79.9, 'feelslike': 87.9, 'dew': 41.6, 'humidity': 18.4, 'precip': 0.0, 'precipprob': 0.0, 'precipcover': 0.0, 'preciptype': nan, 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 21.5, 'windspeed': 10.7, 'winddir': 201.9, 'pressure': 1000.8, 'cloudcover': 4.0, 'visibility': 15.0, 'solarradiation': 272.7, 'solarenergy': 23.6, 'uvindex': 9.0, 'severerisk': 10.0, 'sunrise': '06:10:09', 'sunriseEpoch': 1726146609.0, 'sunset': '18:38:04', 'sunsetEpoch': 1726191484.0, 'moonphase': 0.32, 'conditions': 'Clear', 'description': 'Clear conditions throughout the day.', 'icon': 'clear-day', 'stations': nan, 'source': 'fcst', 'City': 'Phoenix', 'Temp_Range': 21.40000000000001, 'Heat_Index': 87.60290690670004, 'Severity_Score': 3.95, 'Condition_Code': 0.0, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Thursday', 'Is_Weekend': False, 'Health_Risk_Score': 9.487090690670003}
# 6: {'_id': ObjectId('67082952b0379fdf34f00c3d'), 'datetime': '2024-09-13', 'datetimeEpoch': 1726210800.0, 'tempmax': 101.2, 'tempmin': 77.6, 'temp': 89.3, 'feelslikemax': 96.9, 'feelslikemin': 77.6, 'feelslike': 86.4, 'dew': 42.6, 'humidity': 20.4, 'precip': 0.0, 'precipprob': 0.0, 'precipcover': 0.0, 'preciptype': nan, 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 14.3, 'windspeed': 7.2, 'winddir': 192.9, 'pressure': 1006.3, 'cloudcover': 7.2, 'visibility': 15.0, 'solarradiation': 269.5, 'solarenergy': 23.1, 'uvindex': 9.0, 'severerisk': 10.0, 'sunrise': '06:10:49', 'sunriseEpoch': 1726233049.0, 'sunset': '18:36:41', 'sunsetEpoch': 1726277801.0, 'moonphase': 0.36, 'conditions': 'Clear', 'description': 'Clear conditions throughout the day.', 'icon': 'clear-day', 'stations': nan, 'source': 'fcst', 'City': 'Phoenix', 'Temp_Range': 23.60000000000001, 'Heat_Index': 85.71988263588409, 'Severity_Score': 3.2300000000000004, 'Condition_Code': 0.0, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Friday', 'Is_Weekend': False, 'Health_Risk_Score': 9.23090826358841}
# 7: {'_id': ObjectId('67082952b0379fdf34f00c3e'), 'datetime': '2024-09-14', 'datetimeEpoch': 1726297200.0, 'tempmax': 99.4, 'tempmin': 78.2, 'temp': 89.1, 'feelslikemax': 96.1, 'feelslikemin': 78.2, 'feelslike': 86.8, 'dew': 48.4, 'humidity': 25.3, 'precip': 0.004, 'precipprob': 6.0, 'precipcover': 4.17, 'preciptype': "['rain']", 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 12.1, 'windspeed': 5.4, 'winddir': 224.8, 'pressure': 1008.7, 'cloudcover': 9.6, 'visibility': 15.0, 'solarradiation': 262.5, 'solarenergy': 22.6, 'uvindex': 9.0, 'severerisk': 10.0, 'sunrise': '06:11:29', 'sunriseEpoch': 1726319489.0, 'sunset': '18:35:19', 'sunsetEpoch': 1726364119.0, 'moonphase': 0.39, 'conditions': 'Clear', 'description': 'Clear conditions throughout the day.', 'icon': 'clear-day', 'stations': nan, 'source': 'fcst', 'City': 'Phoenix', 'Temp_Range': 21.200000000000003, 'Heat_Index': 86.11250590362911, 'Severity_Score': 3.0104, 'Condition_Code': 0.0, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Saturday', 'Is_Weekend': True, 'Health_Risk_Score': 9.37288179036291}
# 8: {'_id': ObjectId('67082952b0379fdf34f00c3f'), 'datetime': '2024-09-15', 'datetimeEpoch': 1726383600.0, 'tempmax': 100.1, 'tempmin': 82.1, 'temp': 92.0, 'feelslikemax': 100.6, 'feelslikemin': 81.5, 'feelslike': 92.3, 'dew': 60.3, 'humidity': 35.8, 'precip': 0.012, 'precipprob': 12.9, 'precipcover': 4.17, 'preciptype': "['rain']", 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 19.0, 'windspeed': 11.6, 'winddir': 254.3, 'pressure': 1007.3, 'cloudcover': 1.8, 'visibility': 14.0, 'solarradiation': 259.9, 'solarenergy': 22.3, 'uvindex': 8.0, 'severerisk': 30.0, 'sunrise': '06:12:09', 'sunriseEpoch': 1726405929.0, 'sunset': '18:33:56', 'sunsetEpoch': 1726450436.0, 'moonphase': 0.42, 'conditions': 'Clear', 'description': 'Clear conditions throughout the day.', 'icon': 'clear-day', 'stations': nan, 'source': 'fcst', 'City': 'Phoenix', 'Temp_Range': 18.0, 'Heat_Index': 92.16758603040012, 'Severity_Score': 3.5012, 'Condition_Code': 0.0, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Sunday', 'Is_Weekend': True, 'Health_Risk_Score': 10.470188203040012}
# 9: {'_id': ObjectId('67082952b0379fdf34f00c40'), 'datetime': '2024-09-16', 'datetimeEpoch': 1726470000.0, 'tempmax': 99.6, 'tempmin': 86.1, 'temp': 92.2, 'feelslikemax': 99.7, 'feelslikemin': 87.4, 'feelslike': 93.0, 'dew': 62.2, 'humidity': 37.8, 'precip': 0.0, 'precipprob': 12.9, 'precipcover': 0.0, 'preciptype': nan, 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 17.7, 'windspeed': 12.1, 'winddir': 222.5, 'pressure': 1006.8, 'cloudcover': 12.2, 'visibility': 15.0, 'solarradiation': 245.3, 'solarenergy': 21.3, 'uvindex': 8.0, 'severerisk': 30.0, 'sunrise': '06:12:49', 'sunriseEpoch': 1726492369.0, 'sunset': '18:32:33', 'sunsetEpoch': 1726536753.0, 'moonphase': 0.46, 'conditions': 'Clear', 'description': 'Clear conditions throughout the day.', 'icon': 'clear-day', 'stations': nan, 'source': 'fcst', 'City': 'Phoenix', 'Temp_Range': 13.5, 'Heat_Index': 93.20895235529596, 'Severity_Score': 3.37, 'Condition_Code': 0.0, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Monday', 'Is_Weekend': False, 'Health_Risk_Score': 10.594755235529597}
# 10: {'_id': ObjectId('67082952b0379fdf34f00c41'), 'datetime': '2024-09-17', 'datetimeEpoch': 1726556400.0, 'tempmax': 100.7, 'tempmin': 85.7, 'temp': 92.2, 'feelslikemax': 98.5, 'feelslikemin': 85.2, 'feelslike': 91.2, 'dew': 57.3, 'humidity': 31.8, 'precip': 0.0, 'precipprob': 19.4, 'precipcover': 0.0, 'preciptype': nan, 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 21.5, 'windspeed': 18.3, 'winddir': 234.6, 'pressure': 1005.6, 'cloudcover': 34.7, 'visibility': 15.0, 'solarradiation': 246.5, 'solarenergy': 21.2, 'uvindex': 8.0, 'severerisk': 10.0, 'sunrise': '06:13:29', 'sunriseEpoch': 1726578809.0, 'sunset': '18:31:10', 'sunsetEpoch': 1726623070.0, 'moonphase': 0.5, 'conditions': 'Partially cloudy', 'description': 'Partly cloudy throughout the day.', 'icon': 'partly-cloudy-day', 'stations': nan, 'source': 'fcst', 'City': 'Phoenix', 'Temp_Range': 15.0, 'Heat_Index': 91.13188727945612, 'Severity_Score': 3.75, 'Condition_Code': nan, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Tuesday', 'Is_Weekend': False, 'Health_Risk_Score': 10.305688727945611}
# 11: {'_id': ObjectId('67082952b0379fdf34f00c42'), 'datetime': '2024-09-18', 'datetimeEpoch': 1726642800.0, 'tempmax': 98.3, 'tempmin': 83.2, 'temp': 90.1, 'feelslikemax': 93.5, 'feelslikemin': 80.7, 'feelslike': 86.4, 'dew': 39.2, 'humidity': 17.4, 'precip': 0.0, 'precipprob': 6.5, 'precipcover': 0.0, 'preciptype': nan, 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 15.7, 'windspeed': 10.1, 'winddir': 247.2, 'pressure': 1007.1, 'cloudcover': 0.0, 'visibility': 15.0, 'solarradiation': 267.3, 'solarenergy': 23.1, 'uvindex': 9.0, 'severerisk': 10.0, 'sunrise': '06:14:09', 'sunriseEpoch': 1726665249.0, 'sunset': '18:29:47', 'sunsetEpoch': 1726709387.0, 'moonphase': 0.52, 'conditions': 'Clear', 'description': 'Clear conditions throughout the day.', 'icon': 'clear-day', 'stations': nan, 'source': 'fcst', 'City': 'Phoenix', 'Temp_Range': 15.099999999999994, 'Heat_Index': 86.20360304705606, 'Severity_Score': 3.37, 'Condition_Code': 0.0, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Wednesday', 'Is_Weekend': False, 'Health_Risk_Score': 9.206740304705606}
# 12: {'_id': ObjectId('67082952b0379fdf34f00c43'), 'datetime': '2024-09-19', 'datetimeEpoch': 1726729200.0, 'tempmax': 97.4, 'tempmin': 81.8, 'temp': 89.1, 'feelslikemax': 92.2, 'feelslikemin': 79.6, 'feelslike': 85.3, 'dew': 29.0, 'humidity': 12.4, 'precip': 0.0, 'precipprob': 6.5, 'precipcover': 0.0, 'preciptype': nan, 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 12.5, 'windspeed': 8.7, 'winddir': 258.9, 'pressure': 1007.8, 'cloudcover': 9.6, 'visibility': 15.0, 'solarradiation': 271.1, 'solarenergy': 23.4, 'uvindex': 9.0, 'severerisk': 10.0, 'sunrise': '06:14:50', 'sunriseEpoch': 1726751690.0, 'sunset': '18:28:24', 'sunsetEpoch': 1726795704.0, 'moonphase': 0.56, 'conditions': 'Clear', 'description': 'Clear conditions throughout the day.', 'icon': 'clear-day', 'stations': nan, 'source': 'fcst', 'City': 'Phoenix', 'Temp_Range': 15.600000000000009, 'Heat_Index': 85.14708197583606, 'Severity_Score': 3.05, 'Condition_Code': 0.0, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Thursday', 'Is_Weekend': False, 'Health_Risk_Score': 8.892908197583605}
# 13: {'_id': ObjectId('67082952b0379fdf34f00c44'), 'datetime': '2024-09-20', 'datetimeEpoch': 1726815600.0, 'tempmax': 94.6, 'tempmin': 82.5, 'temp': 87.9, 'feelslikemax': 89.9, 'feelslikemin': 80.1, 'feelslike': 84.4, 'dew': 35.5, 'humidity': 15.8, 'precip': 0.004, 'precipprob': 6.5, 'precipcover': 4.17, 'preciptype': "['rain']", 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 15.4, 'windspeed': 9.8, 'winddir': 238.1, 'pressure': 1007.4, 'cloudcover': 92.0, 'visibility': 15.0, 'solarradiation': 175.8, 'solarenergy': 15.3, 'uvindex': 6.0, 'severerisk': 10.0, 'sunrise': '06:15:30', 'sunriseEpoch': 1726838130.0, 'sunset': '18:27:01', 'sunsetEpoch': 1726882021.0, 'moonphase': 0.59, 'conditions': 'Overcast', 'description': 'Cloudy skies throughout the day.', 'icon': 'cloudy', 'stations': nan, 'source': 'fcst', 'City': 'Phoenix', 'Temp_Range': 12.099999999999994, 'Heat_Index': 84.20944151646408, 'Severity_Score': 2.7404, 'Condition_Code': nan, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Friday', 'Is_Weekend': False, 'Health_Risk_Score': 8.853927351646409}
# 14: {'_id': ObjectId('67082952b0379fdf34f00c45'), 'datetime': '2024-09-21', 'datetimeEpoch': 1726902000.0, 'tempmax': 93.6, 'tempmin': 77.4, 'temp': 85.8, 'feelslikemax': 89.0, 'feelslikemin': 77.4, 'feelslike': 83.1, 'dew': 28.7, 'humidity': 13.7, 'precip': 0.0, 'precipprob': 3.2, 'precipcover': 0.0, 'preciptype': nan, 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 14.1, 'windspeed': 9.2, 'winddir': 271.6, 'pressure': 1009.3, 'cloudcover': 1.8, 'visibility': 15.0, 'solarradiation': 268.6, 'solarenergy': 23.3, 'uvindex': 9.0, 'severerisk': 10.0, 'sunrise': '06:16:10', 'sunriseEpoch': 1726924570.0, 'sunset': '18:25:39', 'sunsetEpoch': 1726968339.0, 'moonphase': 0.63, 'conditions': 'Clear', 'description': 'Clear conditions throughout the day.', 'icon': 'clear-day', 'stations': nan, 'source': 'fcst', 'City': 'Phoenix', 'Temp_Range': 16.19999999999999, 'Heat_Index': 82.48084148677607, 'Severity_Score': 3.21, 'Condition_Code': 0.0, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Saturday', 'Is_Weekend': True, 'Health_Risk_Score': 8.687854148677607}
# 15: {'_id': ObjectId('67082952b0379fdf34f00c46'), 'datetime': '2024-09-07', 'datetimeEpoch': 1725692400.0, 'tempmax': 89.0, 'tempmin': 62.1, 'temp': 73.3, 'feelslikemax': 88.6, 'feelslikemin': 62.1, 'feelslike': 73.3, 'dew': 59.8, 'humidity': 66.3, 'precip': 0.0, 'precipprob': 0.0, 'precipcover': 0.0, 'preciptype': nan, 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 16.1, 'windspeed': 9.2, 'winddir': 311.1, 'pressure': 1012.2, 'cloudcover': 12.0, 'visibility': 10.0, 'solarradiation': 267.7, 'solarenergy': 23.4, 'uvindex': 9.0, 'severerisk': 10.0, 'sunrise': '06:43:31', 'sunriseEpoch': 1725716611.0, 'sunset': '19:26:34', 'sunsetEpoch': 1725762394.0, 'moonphase': 0.16, 'conditions': 'Clear', 'description': 'Clear conditions throughout the day.', 'icon': 'clear-day', 'stations': "['KSJC', 'KLVK', 'E6873', 'KHWD', 'KWVI', 'KOAK']", 'source': 'comb', 'City': 'San Jose', 'Temp_Range': 26.9, 'Heat_Index': 75.84249614266135, 'Severity_Score': 3.41, 'Condition_Code': 0.0, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Saturday', 'Is_Weekend': True, 'Health_Risk_Score': 9.845079614266137}
# 16: {'_id': ObjectId('67082952b0379fdf34f00c47'), 'datetime': '2024-09-08', 'datetimeEpoch': 1725778800.0, 'tempmax': 89.0, 'tempmin': 60.0, 'temp': 72.4, 'feelslikemax': 87.9, 'feelslikemin': 60.0, 'feelslike': 72.3, 'dew': 57.6, 'humidity': 62.5, 'precip': 0.0, 'precipprob': 0.0, 'precipcover': 0.0, 'preciptype': nan, 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 13.9, 'windspeed': 8.1, 'winddir': 310.2, 'pressure': 1012.1, 'cloudcover': 15.6, 'visibility': 9.8, 'solarradiation': 279.0, 'solarenergy': 24.1, 'uvindex': 9.0, 'severerisk': 10.0, 'sunrise': '06:44:20', 'sunriseEpoch': 1725803060.0, 'sunset': '19:25:03', 'sunsetEpoch': 1725848703.0, 'moonphase': 0.19, 'conditions': 'Clear', 'description': 'Clear conditions throughout the day.', 'icon': 'clear-day', 'stations': nan, 'source': 'fcst', 'City': 'San Jose', 'Temp_Range': 29.0, 'Heat_Index': 75.92701658370012, 'Severity_Score': 3.1900000000000004, 'Condition_Code': 0.0, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Sunday', 'Is_Weekend': True, 'Health_Risk_Score': 9.586451658370011}
# 17: {'_id': ObjectId('67082952b0379fdf34f00c48'), 'datetime': '2024-09-09', 'datetimeEpoch': 1725865200.0, 'tempmax': 88.1, 'tempmin': 63.1, 'temp': 73.1, 'feelslikemax': 87.4, 'feelslikemin': 63.1, 'feelslike': 73.0, 'dew': 57.4, 'humidity': 59.9, 'precip': 0.0, 'precipprob': 0.0, 'precipcover': 0.0, 'preciptype': nan, 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 16.1, 'windspeed': 9.2, 'winddir': 296.7, 'pressure': 1013.0, 'cloudcover': 11.0, 'visibility': 10.1, 'solarradiation': 311.5, 'solarenergy': 27.0, 'uvindex': 9.0, 'severerisk': 10.0, 'sunrise': '06:45:10', 'sunriseEpoch': 1725889510.0, 'sunset': '19:23:32', 'sunsetEpoch': 1725935012.0, 'moonphase': 0.22, 'conditions': 'Clear', 'description': 'Clear conditions throughout the day.', 'icon': 'clear-day', 'stations': nan, 'source': 'fcst', 'City': 'San Jose', 'Temp_Range': 25.0, 'Heat_Index': 76.45640756034118, 'Severity_Score': 3.41, 'Condition_Code': 0.0, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Monday', 'Is_Weekend': False, 'Health_Risk_Score': 9.688230756034118}
# 18: {'_id': ObjectId('67082952b0379fdf34f00c49'), 'datetime': '2024-09-10', 'datetimeEpoch': 1725951600.0, 'tempmax': 79.4, 'tempmin': 59.6, 'temp': 67.8, 'feelslikemax': 79.4, 'feelslikemin': 59.6, 'feelslike': 67.8, 'dew': 57.2, 'humidity': 70.7, 'precip': 0.0, 'precipprob': 0.0, 'precipcover': 0.0, 'preciptype': nan, 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 17.4, 'windspeed': 9.8, 'winddir': 290.2, 'pressure': 1012.5, 'cloudcover': 18.8, 'visibility': 12.4, 'solarradiation': 274.7, 'solarenergy': 23.8, 'uvindex': 9.0, 'severerisk': 10.0, 'sunrise': '06:45:59', 'sunriseEpoch': 1725975959.0, 'sunset': '19:22:01', 'sunsetEpoch': 1726021321.0, 'moonphase': 0.25, 'conditions': 'Clear', 'description': 'Clear conditions throughout the day.', 'icon': 'clear-day', 'stations': nan, 'source': 'fcst', 'City': 'San Jose', 'Temp_Range': 19.800000000000004, 'Heat_Index': 73.51643181157598, 'Severity_Score': 3.54, 'Condition_Code': 0.0, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Tuesday', 'Is_Weekend': False, 'Health_Risk_Score': 9.8544231811576}
# 19: {'_id': ObjectId('67082952b0379fdf34f00c4a'), 'datetime': '2024-09-11', 'datetimeEpoch': 1726038000.0, 'tempmax': 77.3, 'tempmin': 57.6, 'temp': 66.3, 'feelslikemax': 77.3, 'feelslikemin': 57.6, 'feelslike': 66.3, 'dew': 56.8, 'humidity': 73.1, 'precip': 0.0, 'precipprob': 4.0, 'precipcover': 0.0, 'preciptype': nan, 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 23.0, 'windspeed': 13.4, 'winddir': 273.9, 'pressure': 1009.6, 'cloudcover': 17.3, 'visibility': 15.0, 'solarradiation': 264.0, 'solarenergy': 22.6, 'uvindex': 8.0, 'severerisk': 10.0, 'sunrise': '06:46:48', 'sunriseEpoch': 1726062408.0, 'sunset': '19:20:29', 'sunsetEpoch': 1726107629.0, 'moonphase': 0.29, 'conditions': 'Clear', 'description': 'Clear conditions throughout the day.', 'icon': 'clear-day', 'stations': nan, 'source': 'fcst', 'City': 'San Jose', 'Temp_Range': 19.7, 'Heat_Index': 72.90603255502886, 'Severity_Score': 3.9, 'Condition_Code': 0.0, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Wednesday', 'Is_Weekend': False, 'Health_Risk_Score': 10.141503255502885}
# 20: {'_id': ObjectId('67082952b0379fdf34f00c4b'), 'datetime': '2024-09-12', 'datetimeEpoch': 1726124400.0, 'tempmax': 79.2, 'tempmin': 57.8, 'temp': 67.4, 'feelslikemax': 79.2, 'feelslikemin': 57.8, 'feelslike': 67.4, 'dew': 55.6, 'humidity': 68.3, 'precip': 0.0, 'precipprob': 5.0, 'precipcover': 0.0, 'preciptype': nan, 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 17.9, 'windspeed': 10.7, 'winddir': 285.8, 'pressure': 1007.0, 'cloudcover': 14.2, 'visibility': 15.0, 'solarradiation': 262.2, 'solarenergy': 22.6, 'uvindex': 8.0, 'severerisk': 10.0, 'sunrise': '06:47:38', 'sunriseEpoch': 1726148858.0, 'sunset': '19:18:57', 'sunsetEpoch': 1726193937.0, 'moonphase': 0.32, 'conditions': 'Clear', 'description': 'Clear conditions throughout the day.', 'icon': 'clear-day', 'stations': nan, 'source': 'fcst', 'City': 'San Jose', 'Temp_Range': 21.40000000000001, 'Heat_Index': 74.30085574530415, 'Severity_Score': 3.39, 'Condition_Code': 0.0, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Thursday', 'Is_Weekend': False, 'Health_Risk_Score': 9.745455574530414}
# 21: {'_id': ObjectId('67082952b0379fdf34f00c4c'), 'datetime': '2024-09-13', 'datetimeEpoch': 1726210800.0, 'tempmax': 83.2, 'tempmin': 58.9, 'temp': 69.6, 'feelslikemax': 82.2, 'feelslikemin': 58.9, 'feelslike': 69.5, 'dew': 54.2, 'humidity': 60.5, 'precip': 0.0, 'precipprob': 0.0, 'precipcover': 0.0, 'preciptype': nan, 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 16.1, 'windspeed': 8.9, 'winddir': 287.5, 'pressure': 1007.4, 'cloudcover': 5.9, 'visibility': 15.0, 'solarradiation': 263.2, 'solarenergy': 22.5, 'uvindex': 8.0, 'severerisk': 10.0, 'sunrise': '06:48:27', 'sunriseEpoch': 1726235307.0, 'sunset': '19:17:25', 'sunsetEpoch': 1726280245.0, 'moonphase': 0.36, 'conditions': 'Clear', 'description': 'Clear conditions throughout the day.', 'icon': 'clear-day', 'stations': nan, 'source': 'fcst', 'City': 'San Jose', 'Temp_Range': 24.300000000000004, 'Heat_Index': 75.81915810730015, 'Severity_Score': 3.21, 'Condition_Code': 0.0, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Friday', 'Is_Weekend': False, 'Health_Risk_Score': 9.523965810730015}
# 22: {'_id': ObjectId('67082952b0379fdf34f00c4d'), 'datetime': '2024-09-14', 'datetimeEpoch': 1726297200.0, 'tempmax': 81.4, 'tempmin': 59.4, 'temp': 68.8, 'feelslikemax': 81.3, 'feelslikemin': 59.4, 'feelslike': 68.8, 'dew': 55.5, 'humidity': 64.2, 'precip': 0.0, 'precipprob': 1.0, 'precipcover': 0.0, 'preciptype': nan, 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 16.6, 'windspeed': 9.8, 'winddir': 263.1, 'pressure': 1010.3, 'cloudcover': 8.9, 'visibility': 14.9, 'solarradiation': 259.1, 'solarenergy': 22.3, 'uvindex': 8.0, 'severerisk': 10.0, 'sunrise': '06:49:17', 'sunriseEpoch': 1726321757.0, 'sunset': '19:15:53', 'sunsetEpoch': 1726366553.0, 'moonphase': 0.39, 'conditions': 'Clear', 'description': 'Clear conditions throughout the day.', 'icon': 'clear-day', 'stations': nan, 'source': 'fcst', 'City': 'San Jose', 'Temp_Range': 22.000000000000007, 'Heat_Index': 75.16348200137604, 'Severity_Score': 3.26, 'Condition_Code': 0.0, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Saturday', 'Is_Weekend': True, 'Health_Risk_Score': 9.609268200137604}
# 23: {'_id': ObjectId('67082952b0379fdf34f00c4e'), 'datetime': '2024-09-15', 'datetimeEpoch': 1726383600.0, 'tempmax': 78.3, 'tempmin': 59.8, 'temp': 66.8, 'feelslikemax': 78.3, 'feelslikemin': 59.8, 'feelslike': 66.8, 'dew': 47.3, 'humidity': 52.9, 'precip': 0.0, 'precipprob': 3.2, 'precipcover': 0.0, 'preciptype': nan, 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 9.8, 'windspeed': 8.9, 'winddir': 256.5, 'pressure': 1011.5, 'cloudcover': 3.1, 'visibility': 14.9, 'solarradiation': 255.1, 'solarenergy': 22.0, 'uvindex': 8.0, 'severerisk': 10.0, 'sunrise': '06:50:06', 'sunriseEpoch': 1726408206.0, 'sunset': '19:14:21', 'sunsetEpoch': 1726452861.0, 'moonphase': 0.42, 'conditions': 'Clear', 'description': 'Clear conditions throughout the day.', 'icon': 'clear-day', 'stations': nan, 'source': 'fcst', 'City': 'San Jose', 'Temp_Range': 18.5, 'Heat_Index': 77.56033359368409, 'Severity_Score': 2.58, 'Condition_Code': 0.0, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Sunday', 'Is_Weekend': True, 'Health_Risk_Score': 9.12085335936841}
# 24: {'_id': ObjectId('67082952b0379fdf34f00c4f'), 'datetime': '2024-09-16', 'datetimeEpoch': 1726470000.0, 'tempmax': 81.2, 'tempmin': 59.3, 'temp': 68.9, 'feelslikemax': 79.6, 'feelslikemin': 59.3, 'feelslike': 68.6, 'dew': 44.4, 'humidity': 43.5, 'precip': 0.0, 'precipprob': 0.0, 'precipcover': 0.0, 'preciptype': nan, 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 7.8, 'windspeed': 8.1, 'winddir': 287.5, 'pressure': 1010.1, 'cloudcover': 8.6, 'visibility': 15.0, 'solarradiation': 249.6, 'solarenergy': 21.7, 'uvindex': 8.0, 'severerisk': 10.0, 'sunrise': '06:50:56', 'sunriseEpoch': 1726494656.0, 'sunset': '19:12:49', 'sunsetEpoch': 1726539169.0, 'moonphase': 0.46, 'conditions': 'Clear', 'description': 'Clear conditions throughout the day.', 'icon': 'clear-day', 'stations': nan, 'source': 'fcst', 'City': 'San Jose', 'Temp_Range': 21.90000000000001, 'Heat_Index': 77.26954857032499, 'Severity_Score': 2.38, 'Condition_Code': 0.0, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Monday', 'Is_Weekend': False, 'Health_Risk_Score': 8.762254857032499}
# 25: {'_id': ObjectId('67082952b0379fdf34f00c50'), 'datetime': '2024-09-17', 'datetimeEpoch': 1726556400.0, 'tempmax': 82.3, 'tempmin': 60.9, 'temp': 68.5, 'feelslikemax': 80.2, 'feelslikemin': 60.9, 'feelslike': 68.4, 'dew': 46.6, 'humidity': 47.6, 'precip': 0.0, 'precipprob': 0.0, 'precipcover': 0.0, 'preciptype': nan, 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 8.5, 'windspeed': 10.3, 'winddir': 279.9, 'pressure': 1009.1, 'cloudcover': 14.2, 'visibility': 14.9, 'solarradiation': 245.6, 'solarenergy': 21.3, 'uvindex': 8.0, 'severerisk': 10.0, 'sunrise': '06:51:45', 'sunriseEpoch': 1726581105.0, 'sunset': '19:11:16', 'sunsetEpoch': 1726625476.0, 'moonphase': 0.5, 'conditions': 'Clear', 'description': 'Clear conditions throughout the day.', 'icon': 'clear-day', 'stations': nan, 'source': 'fcst', 'City': 'San Jose', 'Temp_Range': 21.4, 'Heat_Index': 77.32153682110014, 'Severity_Score': 2.45, 'Condition_Code': 0.0, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Tuesday', 'Is_Weekend': False, 'Health_Risk_Score': 8.898353682110015}
# 26: {'_id': ObjectId('67082952b0379fdf34f00c51'), 'datetime': '2024-09-18', 'datetimeEpoch': 1726642800.0, 'tempmax': 76.9, 'tempmin': 57.6, 'temp': 64.9, 'feelslikemax': 76.9, 'feelslikemin': 57.6, 'feelslike': 64.9, 'dew': 49.2, 'humidity': 58.3, 'precip': 0.0, 'precipprob': 0.0, 'precipcover': 0.0, 'preciptype': nan, 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 9.2, 'windspeed': 10.7, 'winddir': 277.8, 'pressure': 1011.5, 'cloudcover': 20.0, 'visibility': 14.9, 'solarradiation': 241.5, 'solarenergy': 20.9, 'uvindex': 8.0, 'severerisk': 10.0, 'sunrise': '06:52:35', 'sunriseEpoch': 1726667555.0, 'sunset': '19:09:44', 'sunsetEpoch': 1726711784.0, 'moonphase': 0.52, 'conditions': 'Clear', 'description': 'Becoming cloudy in the afternoon.', 'icon': 'clear-day', 'stations': nan, 'source': 'fcst', 'City': 'San Jose', 'Temp_Range': 19.300000000000004, 'Heat_Index': 77.801748442029, 'Severity_Score': 2.52, 'Condition_Code': 0.0, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Wednesday', 'Is_Weekend': False, 'Health_Risk_Score': 9.2493348442029}
# 27: {'_id': ObjectId('67082952b0379fdf34f00c52'), 'datetime': '2024-09-19', 'datetimeEpoch': 1726729200.0, 'tempmax': 75.5, 'tempmin': 57.6, 'temp': 64.7, 'feelslikemax': 75.5, 'feelslikemin': 57.6, 'feelslike': 64.7, 'dew': 48.5, 'humidity': 57.7, 'precip': 0.0, 'precipprob': 3.2, 'precipcover': 0.0, 'preciptype': nan, 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 8.3, 'windspeed': 8.7, 'winddir': 290.8, 'pressure': 1012.7, 'cloudcover': 0.1, 'visibility': 14.8, 'solarradiation': 240.3, 'solarenergy': 20.9, 'uvindex': 8.0, 'severerisk': 10.0, 'sunrise': '06:53:25', 'sunriseEpoch': 1726754005.0, 'sunset': '19:08:11', 'sunsetEpoch': 1726798091.0, 'moonphase': 0.56, 'conditions': 'Clear', 'description': 'Clear conditions throughout the day.', 'icon': 'clear-day', 'stations': nan, 'source': 'fcst', 'City': 'San Jose', 'Temp_Range': 17.9, 'Heat_Index': 78.03617693414107, 'Severity_Score': 2.43, 'Condition_Code': 0.0, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Thursday', 'Is_Weekend': False, 'Health_Risk_Score': 9.205727693414106}
# 28: {'_id': ObjectId('67082952b0379fdf34f00c53'), 'datetime': '2024-09-20', 'datetimeEpoch': 1726815600.0, 'tempmax': 80.5, 'tempmin': 59.3, 'temp': 67.1, 'feelslikemax': 79.6, 'feelslikemin': 59.3, 'feelslike': 67.0, 'dew': 49.8, 'humidity': 56.1, 'precip': 0.0, 'precipprob': 0.0, 'precipcover': 0.0, 'preciptype': nan, 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 9.8, 'windspeed': 10.3, 'winddir': 278.8, 'pressure': 1011.0, 'cloudcover': 0.4, 'visibility': 14.9, 'solarradiation': 237.6, 'solarenergy': 20.6, 'uvindex': 8.0, 'severerisk': 10.0, 'sunrise': '06:54:15', 'sunriseEpoch': 1726840455.0, 'sunset': '19:06:39', 'sunsetEpoch': 1726884399.0, 'moonphase': 0.59, 'conditions': 'Clear', 'description': 'Clear conditions throughout the day.', 'icon': 'clear-day', 'stations': nan, 'source': 'fcst', 'City': 'San Jose', 'Temp_Range': 21.200000000000003, 'Heat_Index': 77.05373333982106, 'Severity_Score': 2.58, 'Condition_Code': 0.0, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Friday', 'Is_Weekend': False, 'Health_Risk_Score': 9.152753333982108}
# 29: {'_id': ObjectId('67082952b0379fdf34f00c54'), 'datetime': '2024-09-21', 'datetimeEpoch': 1726902000.0, 'tempmax': 76.4, 'tempmin': 61.4, 'temp': 67.4, 'feelslikemax': 76.4, 'feelslikemin': 61.4, 'feelslike': 67.4, 'dew': 54.6, 'humidity': 64.9, 'precip': 0.0, 'precipprob': 0.0, 'precipcover': 0.0, 'preciptype': nan, 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 11.2, 'windspeed': 10.5, 'winddir': 296.3, 'pressure': 1012.5, 'cloudcover': 59.0, 'visibility': 14.9, 'solarradiation': 220.3, 'solarenergy': 18.9, 'uvindex': 8.0, 'severerisk': 10.0, 'sunrise': '06:55:05', 'sunriseEpoch': 1726926905.0, 'sunset': '19:05:06', 'sunsetEpoch': 1726970706.0, 'moonphase': 0.63, 'conditions': 'Partially cloudy', 'description': 'Partly cloudy throughout the day.', 'icon': 'partly-cloudy-day', 'stations': nan, 'source': 'fcst', 'City': 'San Jose', 'Temp_Range': 15.000000000000009, 'Heat_Index': 75.22822184661618, 'Severity_Score': 2.72, 'Condition_Code': nan, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Saturday', 'Is_Weekend': True, 'Health_Risk_Score': 9.288102184661618}
# 30: {'_id': ObjectId('67082952b0379fdf34f00c55'), 'datetime': '2024-09-07', 'datetimeEpoch': 1725685200.0, 'tempmax': 92.0, 'tempmin': 73.4, 'temp': 81.7, 'feelslikemax': 90.3, 'feelslikemin': 73.4, 'feelslike': 81.6, 'dew': 60.3, 'humidity': 51.1, 'precip': 0.0, 'precipprob': 1.0, 'precipcover': 0.0, 'preciptype': nan, 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 28.9, 'windspeed': 18.3, 'winddir': 28.4, 'pressure': 1014.5, 'cloudcover': 7.3, 'visibility': 10.0, 'solarradiation': 282.7, 'solarenergy': 24.3, 'uvindex': 9.0, 'severerisk': 10.0, 'sunrise': '07:14:53', 'sunriseEpoch': 1725711293.0, 'sunset': '19:48:16', 'sunsetEpoch': 1725756496.0, 'moonphase': 0.15, 'conditions': 'Clear', 'description': 'Clear conditions throughout the day.', 'icon': 'clear-day', 'stations': "['KSKF', 'KSSF', 'KSAT', 'F6098']", 'source': 'comb', 'City': 'San Antonio', 'Temp_Range': 18.599999999999994, 'Heat_Index': 82.6036417074691, 'Severity_Score': 4.69, 'Condition_Code': 0.0, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Saturday', 'Is_Weekend': True, 'Health_Risk_Score': 10.656954170746909}
# 31: {'_id': ObjectId('67082952b0379fdf34f00c56'), 'datetime': '2024-09-08', 'datetimeEpoch': 1725771600.0, 'tempmax': 87.0, 'tempmin': 65.9, 'temp': 76.4, 'feelslikemax': 84.2, 'feelslikemin': 65.9, 'feelslike': 75.7, 'dew': 50.9, 'humidity': 42.5, 'precip': 0.0, 'precipprob': 0.0, 'precipcover': 0.0, 'preciptype': nan, 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 23.0, 'windspeed': 13.9, 'winddir': 31.1, 'pressure': 1015.8, 'cloudcover': 3.6, 'visibility': 10.1, 'solarradiation': 309.5, 'solarenergy': 26.6, 'uvindex': 10.0, 'severerisk': 10.0, 'sunrise': '07:15:25', 'sunriseEpoch': 1725797725.0, 'sunset': '19:47:04', 'sunsetEpoch': 1725842824.0, 'moonphase': 0.19, 'conditions': 'Clear', 'description': 'Clear conditions throughout the day.', 'icon': 'clear-day', 'stations': nan, 'source': 'fcst', 'City': 'San Antonio', 'Temp_Range': 21.099999999999994, 'Heat_Index': 78.07182759970016, 'Severity_Score': 4.3, 'Condition_Code': 0.0, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Sunday', 'Is_Weekend': True, 'Health_Risk_Score': 9.634682759970016}
# 32: {'_id': ObjectId('67082952b0379fdf34f00c57'), 'datetime': '2024-09-09', 'datetimeEpoch': 1725858000.0, 'tempmax': 88.1, 'tempmin': 63.9, 'temp': 75.9, 'feelslikemax': 85.7, 'feelslikemin': 63.9, 'feelslike': 75.4, 'dew': 52.0, 'humidity': 44.5, 'precip': 0.0, 'precipprob': 5.0, 'precipcover': 0.0, 'preciptype': nan, 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 19.5, 'windspeed': 11.4, 'winddir': 36.7, 'pressure': 1016.8, 'cloudcover': 16.4, 'visibility': 10.1, 'solarradiation': 343.4, 'solarenergy': 29.5, 'uvindex': 9.0, 'severerisk': 10.0, 'sunrise': '07:15:56', 'sunriseEpoch': 1725884156.0, 'sunset': '19:45:51', 'sunsetEpoch': 1725929151.0, 'moonphase': 0.22, 'conditions': 'Clear', 'description': 'Clear conditions throughout the day.', 'icon': 'clear-day', 'stations': nan, 'source': 'fcst', 'City': 'San Antonio', 'Temp_Range': 24.2, 'Heat_Index': 77.92671675952508, 'Severity_Score': 3.75, 'Condition_Code': 0.0, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Monday', 'Is_Weekend': False, 'Health_Risk_Score': 9.461421675952508}
# 33: {'_id': ObjectId('67082952b0379fdf34f00c58'), 'datetime': '2024-09-10', 'datetimeEpoch': 1725944400.0, 'tempmax': 88.8, 'tempmin': 70.4, 'temp': 79.2, 'feelslikemax': 90.5, 'feelslikemin': 70.4, 'feelslike': 80.0, 'dew': 59.4, 'humidity': 51.3, 'precip': 0.06, 'precipprob': 26.0, 'precipcover': 20.83, 'preciptype': "['rain']", 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 19.5, 'windspeed': 10.7, 'winddir': 42.2, 'pressure': 1013.5, 'cloudcover': 38.9, 'visibility': 12.1, 'solarradiation': 290.4, 'solarenergy': 25.0, 'uvindex': 9.0, 'severerisk': 10.0, 'sunrise': '07:16:26', 'sunriseEpoch': 1725970586.0, 'sunset': '19:44:38', 'sunsetEpoch': 1726015478.0, 'moonphase': 0.25, 'conditions': 'Partially cloudy', 'description': 'Partly cloudy throughout the day.', 'icon': 'partly-cloudy-day', 'stations': nan, 'source': 'fcst', 'City': 'San Antonio', 'Temp_Range': 18.39999999999999, 'Heat_Index': 80.225407608356, 'Severity_Score': 3.756, 'Condition_Code': nan, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Tuesday', 'Is_Weekend': False, 'Health_Risk_Score': 9.9493687608356}
# 34: {'_id': ObjectId('67082952b0379fdf34f00c59'), 'datetime': '2024-09-11', 'datetimeEpoch': 1726030800.0, 'tempmax': 86.6, 'tempmin': 74.9, 'temp': 80.0, 'feelslikemax': 92.7, 'feelslikemin': 74.9, 'feelslike': 82.4, 'dew': 71.0, 'humidity': 74.8, 'precip': 0.056, 'precipprob': 42.0, 'precipcover': 16.67, 'preciptype': "['rain']", 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 18.3, 'windspeed': 10.7, 'winddir': 41.2, 'pressure': 1008.5, 'cloudcover': 51.6, 'visibility': 15.0, 'solarradiation': 194.4, 'solarenergy': 16.7, 'uvindex': 5.0, 'severerisk': 10.0, 'sunrise': '07:16:57', 'sunriseEpoch': 1726057017.0, 'sunset': '19:43:25', 'sunsetEpoch': 1726101805.0, 'moonphase': 0.25, 'conditions': 'Partially cloudy', 'description': 'Partly cloudy throughout the day.', 'icon': 'partly-cloudy-day', 'stations': nan, 'source': 'fcst', 'City': 'San Antonio', 'Temp_Range': 11.699999999999989, 'Heat_Index': 83.54959750320016, 'Severity_Score': 2.8356000000000003, 'Condition_Code': nan, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Wednesday', 'Is_Weekend': False, 'Health_Risk_Score': 10.475988550320018}
# 35: {'_id': ObjectId('67082952b0379fdf34f00c5a'), 'datetime': '2024-09-12', 'datetimeEpoch': 1726117200.0, 'tempmax': 90.1, 'tempmin': 73.7, 'temp': 81.3, 'feelslikemax': 95.2, 'feelslikemin': 73.7, 'feelslike': 83.8, 'dew': 70.2, 'humidity': 70.8, 'precip': 0.244, 'precipprob': 29.0, 'precipcover': 16.67, 'preciptype': "['rain']", 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 13.9, 'windspeed': 7.2, 'winddir': 37.7, 'pressure': 1007.0, 'cloudcover': 28.7, 'visibility': 15.0, 'solarradiation': 269.3, 'solarenergy': 23.1, 'uvindex': 9.0, 'severerisk': 10.0, 'sunrise': '07:17:28', 'sunriseEpoch': 1726143448.0, 'sunset': '19:42:12', 'sunsetEpoch': 1726188132.0, 'moonphase': 0.32, 'conditions': 'Partially cloudy', 'description': 'Partly cloudy throughout the day.', 'icon': 'partly-cloudy-day', 'stations': nan, 'source': 'fcst', 'City': 'San Antonio', 'Temp_Range': 16.39999999999999, 'Heat_Index': 85.30163519543603, 'Severity_Score': 3.2144000000000004, 'Condition_Code': nan, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Thursday', 'Is_Weekend': False, 'Health_Risk_Score': 10.805958719543604}
# 36: {'_id': ObjectId('67082952b0379fdf34f00c5b'), 'datetime': '2024-09-13', 'datetimeEpoch': 1726203600.0, 'tempmax': 92.6, 'tempmin': 75.5, 'temp': 83.3, 'feelslikemax': 98.3, 'feelslikemin': 75.5, 'feelslike': 86.7, 'dew': 71.1, 'humidity': 68.3, 'precip': 0.02, 'precipprob': 23.0, 'precipcover': 8.33, 'preciptype': "['rain']", 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 12.5, 'windspeed': 7.2, 'winddir': 124.3, 'pressure': 1009.8, 'cloudcover': 33.5, 'visibility': 15.0, 'solarradiation': 262.6, 'solarenergy': 22.6, 'uvindex': 9.0, 'severerisk': 10.0, 'sunrise': '07:17:59', 'sunriseEpoch': 1726229879.0, 'sunset': '19:40:58', 'sunsetEpoch': 1726274458.0, 'moonphase': 0.35, 'conditions': 'Partially cloudy', 'description': 'Partly cloudy throughout the day.', 'icon': 'partly-cloudy-day', 'stations': nan, 'source': 'fcst', 'City': 'San Antonio', 'Temp_Range': 17.099999999999994, 'Heat_Index': 88.52007848634103, 'Severity_Score': 3.052, 'Condition_Code': nan, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Friday', 'Is_Weekend': False, 'Health_Risk_Score': 10.936523848634105}
# 37: {'_id': ObjectId('67082952b0379fdf34f00c5c'), 'datetime': '2024-09-14', 'datetimeEpoch': 1726290000.0, 'tempmax': 92.9, 'tempmin': 76.7, 'temp': 84.4, 'feelslikemax': 99.9, 'feelslikemin': 76.7, 'feelslike': 89.1, 'dew': 72.6, 'humidity': 69.1, 'precip': 0.063, 'precipprob': 30.0, 'precipcover': 12.5, 'preciptype': "['rain']", 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 13.2, 'windspeed': 8.1, 'winddir': 132.5, 'pressure': 1011.0, 'cloudcover': 44.1, 'visibility': 15.0, 'solarradiation': 265.3, 'solarenergy': 22.8, 'uvindex': 8.0, 'severerisk': 10.0, 'sunrise': '07:18:30', 'sunriseEpoch': 1726316310.0, 'sunset': '19:39:45', 'sunsetEpoch': 1726360785.0, 'moonphase': 0.39, 'conditions': 'Partially cloudy', 'description': 'Partly cloudy throughout the day.', 'icon': 'partly-cloudy-day', 'stations': nan, 'source': 'fcst', 'City': 'San Antonio', 'Temp_Range': 16.200000000000003, 'Heat_Index': 91.04123081523592, 'Severity_Score': 2.9263, 'Condition_Code': nan, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Saturday', 'Is_Weekend': True, 'Health_Risk_Score': 11.126196381523592}
# 38: {'_id': ObjectId('67082952b0379fdf34f00c5d'), 'datetime': '2024-09-15', 'datetimeEpoch': 1726376400.0, 'tempmax': 98.3, 'tempmin': 77.4, 'temp': 86.6, 'feelslikemax': 99.5, 'feelslikemin': 77.4, 'feelslike': 88.1, 'dew': 66.6, 'humidity': 54.8, 'precip': 0.004, 'precipprob': 29.0, 'precipcover': 4.17, 'preciptype': "['rain']", 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 21.0, 'windspeed': 12.3, 'winddir': 145.8, 'pressure': 1011.4, 'cloudcover': 29.2, 'visibility': 15.0, 'solarradiation': 274.7, 'solarenergy': 23.6, 'uvindex': 8.0, 'severerisk': 10.0, 'sunrise': '07:19:01', 'sunriseEpoch': 1726402741.0, 'sunset': '19:38:31', 'sunsetEpoch': 1726447111.0, 'moonphase': 0.42, 'conditions': 'Partially cloudy', 'description': 'Partly cloudy throughout the day.', 'icon': 'partly-cloudy-day', 'stations': nan, 'source': 'fcst', 'City': 'San Antonio', 'Temp_Range': 20.89999999999999, 'Heat_Index': 90.356070721024, 'Severity_Score': 3.7004, 'Condition_Code': nan, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Sunday', 'Is_Weekend': True, 'Health_Risk_Score': 11.0634262721024}
# 39: {'_id': ObjectId('67082952b0379fdf34f00c5e'), 'datetime': '2024-09-16', 'datetimeEpoch': 1726462800.0, 'tempmax': 95.8, 'tempmin': 75.6, 'temp': 84.8, 'feelslikemax': 95.6, 'feelslikemin': 75.6, 'feelslike': 85.6, 'dew': 64.6, 'humidity': 53.4, 'precip': 0.142, 'precipprob': 22.6, 'precipcover': 8.33, 'preciptype': "['rain']", 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 22.1, 'windspeed': 11.9, 'winddir': 147.7, 'pressure': 1011.9, 'cloudcover': 46.0, 'visibility': 15.0, 'solarradiation': 268.4, 'solarenergy': 23.3, 'uvindex': 8.0, 'severerisk': 10.0, 'sunrise': '07:19:32', 'sunriseEpoch': 1726489172.0, 'sunset': '19:37:17', 'sunsetEpoch': 1726533437.0, 'moonphase': 0.45, 'conditions': 'Partially cloudy', 'description': 'Becoming cloudy in the afternoon.', 'icon': 'partly-cloudy-day', 'stations': nan, 'source': 'fcst', 'City': 'San Antonio', 'Temp_Range': 20.200000000000003, 'Heat_Index': 87.03550035462392, 'Severity_Score': 3.8242, 'Condition_Code': nan, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Monday', 'Is_Weekend': False, 'Health_Risk_Score': 10.745672835462392}
# 40: {'_id': ObjectId('67082952b0379fdf34f00c5f'), 'datetime': '2024-09-17', 'datetimeEpoch': 1726549200.0, 'tempmax': 94.2, 'tempmin': 74.6, 'temp': 83.3, 'feelslikemax': 92.9, 'feelslikemin': 74.6, 'feelslike': 83.8, 'dew': 64.9, 'humidity': 57.1, 'precip': 0.0, 'precipprob': 22.6, 'precipcover': 0.0, 'preciptype': nan, 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 20.1, 'windspeed': 15.4, 'winddir': 127.7, 'pressure': 1011.9, 'cloudcover': 39.9, 'visibility': 15.0, 'solarradiation': 275.1, 'solarenergy': 23.7, 'uvindex': 8.0, 'severerisk': 10.0, 'sunrise': '07:20:03', 'sunriseEpoch': 1726575603.0, 'sunset': '19:36:03', 'sunsetEpoch': 1726619763.0, 'moonphase': 0.5, 'conditions': 'Partially cloudy', 'description': 'Clearing in the afternoon.', 'icon': 'partly-cloudy-day', 'stations': nan, 'source': 'fcst', 'City': 'San Antonio', 'Temp_Range': 19.60000000000001, 'Heat_Index': 85.71944942646917, 'Severity_Score': 3.61, 'Condition_Code': nan, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Tuesday', 'Is_Weekend': False, 'Health_Risk_Score': 10.633254942646918}
# 41: {'_id': ObjectId('67082952b0379fdf34f00c60'), 'datetime': '2024-09-18', 'datetimeEpoch': 1726635600.0, 'tempmax': 95.1, 'tempmin': 72.9, 'temp': 82.6, 'feelslikemax': 94.4, 'feelslikemin': 72.9, 'feelslike': 83.4, 'dew': 66.6, 'humidity': 62.4, 'precip': 0.0, 'precipprob': 16.1, 'precipcover': 0.0, 'preciptype': nan, 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 19.5, 'windspeed': 15.7, 'winddir': 127.1, 'pressure': 1012.3, 'cloudcover': 19.0, 'visibility': 15.0, 'solarradiation': 269.0, 'solarenergy': 23.2, 'uvindex': 8.0, 'severerisk': 10.0, 'sunrise': '07:20:35', 'sunriseEpoch': 1726662035.0, 'sunset': '19:34:49', 'sunsetEpoch': 1726706089.0, 'moonphase': 0.52, 'conditions': 'Clear', 'description': 'Clear conditions throughout the day.', 'icon': 'clear-day', 'stations': nan, 'source': 'fcst', 'City': 'San Antonio', 'Temp_Range': 22.19999999999999, 'Heat_Index': 85.81762362425592, 'Severity_Score': 3.55, 'Condition_Code': 0.0, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Wednesday', 'Is_Weekend': False, 'Health_Risk_Score': 10.79696236242559}
# 42: {'_id': ObjectId('67082952b0379fdf34f00c61'), 'datetime': '2024-09-19', 'datetimeEpoch': 1726722000.0, 'tempmax': 94.9, 'tempmin': 73.5, 'temp': 82.7, 'feelslikemax': 95.8, 'feelslikemin': 73.5, 'feelslike': 84.3, 'dew': 68.3, 'humidity': 65.0, 'precip': 0.004, 'precipprob': 9.7, 'precipcover': 4.17, 'preciptype': "['rain']", 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 19.5, 'windspeed': 9.8, 'winddir': 125.4, 'pressure': 1012.3, 'cloudcover': 63.2, 'visibility': 14.6, 'solarradiation': 233.9, 'solarenergy': 20.1, 'uvindex': 7.0, 'severerisk': 30.0, 'sunrise': '07:21:06', 'sunriseEpoch': 1726748466.0, 'sunset': '19:33:35', 'sunsetEpoch': 1726792415.0, 'moonphase': 0.55, 'conditions': 'Partially cloudy', 'description': 'Partly cloudy throughout the day.', 'icon': 'partly-cloudy-day', 'stations': nan, 'source': 'fcst', 'City': 'San Antonio', 'Temp_Range': 21.40000000000001, 'Heat_Index': 86.5697013268, 'Severity_Score': 3.3504, 'Condition_Code': nan, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Thursday', 'Is_Weekend': False, 'Health_Risk_Score': 10.83473013268}
# 43: {'_id': ObjectId('67082952b0379fdf34f00c62'), 'datetime': '2024-09-20', 'datetimeEpoch': 1726808400.0, 'tempmax': 96.3, 'tempmin': 74.2, 'temp': 83.9, 'feelslikemax': 97.3, 'feelslikemin': 74.2, 'feelslike': 85.2, 'dew': 67.8, 'humidity': 62.0, 'precip': 0.024, 'precipprob': 16.1, 'precipcover': 8.33, 'preciptype': "['rain']", 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 20.6, 'windspeed': 14.1, 'winddir': 121.2, 'pressure': 1011.9, 'cloudcover': 20.8, 'visibility': 15.0, 'solarradiation': 266.3, 'solarenergy': 22.9, 'uvindex': 8.0, 'severerisk': 30.0, 'sunrise': '07:21:37', 'sunriseEpoch': 1726834897.0, 'sunset': '19:32:21', 'sunsetEpoch': 1726878741.0, 'moonphase': 0.59, 'conditions': 'Partially cloudy', 'description': 'Partly cloudy throughout the day.', 'icon': 'partly-cloudy-day', 'stations': nan, 'source': 'fcst', 'City': 'San Antonio', 'Temp_Range': 22.099999999999994, 'Heat_Index': 87.89483698390009, 'Severity_Score': 3.6624, 'Condition_Code': nan, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Friday', 'Is_Weekend': False, 'Health_Risk_Score': 11.06017169839001}
# ...
# 989: {'_id': ObjectId('67082952b0379fdf34f01014'), 'datetime': '2024-09-21', 'datetimeEpoch': 1726914197.4601583, 'tempmax': 95.69575155876342, 'tempmin': 83.28814939210298, 'temp': 90.23872422325957, 'feelslikemax': 95.9674724596664, 'feelslikemin': 82.91394419448211, 'feelslike': 89.46353303885307, 'dew': 62.85232578579062, 'humidity': 39.5421001259902, 'precip': 0.0034683796788736, 'precipprob': 23.11820792339686, 'precipcover': 0.5827647318238625, 'preciptype': nan, 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 22.55345080213168, 'windspeed': 10.801734397837697, 'winddir': 161.82346666228335, 'pressure': 1013.7409043116176, 'cloudcover': 39.35108482119317, 'visibility': 14.935955465715235, 'solarradiation': 194.02164738051428, 'solarenergy': 16.190113881605146, 'uvindex': 6.947536329481274, 'severerisk': 29.393800593502213, 'sunrise': '07:15:05', 'sunriseEpoch': 1726909770.745688, 'sunset': '19:24:32', 'sunsetEpoch': 1726920835.2464256, 'moonphase': 0.6034672157788186, 'conditions': 'Partially cloudy', 'description': 'Becoming cloudy in the afternoon.', 'icon': 'partly-cloudy-day', 'stations': nan, 'source': 'fcst', 'City': 'Dallas', 'Temp_Range': 13.451165580353075, 'Heat_Index': 88.86322182138562, 'Severity_Score': 3.573576927661866, 'Condition_Code': nan, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Saturday', 'Is_Weekend': True, 'Health_Risk_Score': 10.596044079082452}
# 990: {'_id': ObjectId('67082952b0379fdf34f01015'), 'datetime': '2024-09-13', 'datetimeEpoch': 1726175486.2362654, 'tempmax': 101.88904675921944, 'tempmin': 78.49198341717316, 'temp': 87.95377309701126, 'feelslikemax': 99.64400543262664, 'feelslikemin': 77.61099756031531, 'feelslike': 85.65140045746418, 'dew': 43.27638633874942, 'humidity': 19.78834458609204, 'precip': 0.0069298283664787, 'precipprob': 1.98769763516644, 'precipcover': -0.2482574004316305, 'preciptype': nan, 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 13.635669574391224, 'windspeed': 6.988953505614243, 'winddir': 200.84959661654452, 'pressure': 1006.6920306270868, 'cloudcover': 6.721897842320516, 'visibility': 14.905528625926854, 'solarradiation': 262.74259760027206, 'solarenergy': 23.2108183951274, 'uvindex': 8.979890740727404, 'severerisk': 9.774333547162309, 'sunrise': '06:10:49', 'sunriseEpoch': 1726252823.8175352, 'sunset': '18:36:41', 'sunsetEpoch': 1726244605.885675, 'moonphase': 0.3652459170038005, 'conditions': 'Clear', 'description': 'Clear conditions throughout the day.', 'icon': 'clear-day', 'stations': nan, 'source': 'fcst', 'City': 'Phoenix', 'Temp_Range': 23.100771296999483, 'Heat_Index': 84.65618566679967, 'Severity_Score': 3.2707472988402, 'Condition_Code': 0.0, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Friday', 'Is_Weekend': False, 'Health_Risk_Score': 9.24045192685017}
# 991: {'_id': ObjectId('67082952b0379fdf34f01016'), 'datetime': '2024-09-08', 'datetimeEpoch': 1725708405.2121773, 'tempmax': 71.79969362969263, 'tempmin': 53.65298802966806, 'temp': 61.51755067045899, 'feelslikemax': 71.03572519979996, 'feelslikemin': 55.17798890081461, 'feelslike': 62.2295961156849, 'dew': 45.39421216951333, 'humidity': 57.06527328381332, 'precip': -0.0101554152889208, 'precipprob': -0.5091406964942689, 'precipcover': -0.4839132961891843, 'preciptype': nan, 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 20.539267271738563, 'windspeed': 12.969655294318189, 'winddir': 298.24130171019056, 'pressure': 1016.1561013536312, 'cloudcover': 5.436454817105747, 'visibility': 10.091337412196918, 'solarradiation': 277.17053671359315, 'solarenergy': 23.69997699230058, 'uvindex': 8.193348583014963, 'severerisk': 10.681134674079896, 'sunrise': '06:30:22', 'sunriseEpoch': 1725762078.995839, 'sunset': '19:16:00', 'sunsetEpoch': 1725825603.5741415, 'moonphase': 0.1832224718180167, 'conditions': 'Clear', 'description': 'Clear conditions throughout the day.', 'icon': 'clear-day', 'stations': nan, 'source': 'fcst', 'City': 'New York City', 'Temp_Range': 17.31468054576304, 'Heat_Index': 81.25258557168682, 'Severity_Score': 3.590244528599281, 'Condition_Code': 0.0, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Sunday', 'Is_Weekend': True, 'Health_Risk_Score': 9.992650842897769}
# 992: {'_id': ObjectId('67082952b0379fdf34f01017'), 'datetime': '2024-09-14', 'datetimeEpoch': 1726324339.9349942, 'tempmax': 81.74612209280176, 'tempmin': 57.92061165126442, 'temp': 68.28973426709034, 'feelslikemax': 81.70591185683595, 'feelslikemin': 59.05264289787935, 'feelslike': 68.08103954629507, 'dew': 55.53434853960855, 'humidity': 65.83366751383659, 'precip': -0.0061385620042308, 'precipprob': 1.6205090644009694, 'precipcover': 0.4908390741293414, 'preciptype': nan, 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 16.153804998329132, 'windspeed': 9.802508660671766, 'winddir': 262.7384175470823, 'pressure': 1010.439757068691, 'cloudcover': 7.98739781948177, 'visibility': 15.070648532744952, 'solarradiation': 267.7554466649405, 'solarenergy': 22.9155191176557, 'uvindex': 8.008525784925224, 'severerisk': 10.159579573002018, 'sunrise': '06:49:17', 'sunriseEpoch': 1726303722.6126804, 'sunset': '19:15:53', 'sunsetEpoch': 1726376300.5104585, 'moonphase': 0.3861693636508468, 'conditions': 'Clear', 'description': 'Clear conditions throughout the day.', 'icon': 'clear-day', 'stations': nan, 'source': 'fcst', 'City': 'San Jose', 'Temp_Range': 22.078094557169205, 'Heat_Index': 75.57252819580282, 'Severity_Score': 3.33735540246771, 'Condition_Code': 0.0, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Saturday', 'Is_Weekend': True, 'Health_Risk_Score': 9.672304219710371}
# 993: {'_id': ObjectId('67082952b0379fdf34f01018'), 'datetime': '2024-09-21', 'datetimeEpoch': 1726878269.714957, 'tempmax': 83.47610093475241, 'tempmin': 70.29965070708151, 'temp': 74.7694522765621, 'feelslikemax': 83.68241325827412, 'feelslikemin': 70.9265262527191, 'feelslike': 75.64138437807411, 'dew': 59.36360250250752, 'humidity': 56.26561829168596, 'precip': 0.4527229667463913, 'precipprob': 13.934624335155489, 'precipcover': 4.668726240187659, 'preciptype': "['rain']", 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 11.88232049500907, 'windspeed': 9.962767214612107, 'winddir': 107.79407975920785, 'pressure': 1018.6851075945244, 'cloudcover': 34.14960805031401, 'visibility': 14.94585625198865, 'solarradiation': 223.3052999259675, 'solarenergy': 18.418863682229432, 'uvindex': 6.733374960132702, 'severerisk': 10.264639777147517, 'sunrise': '06:43:05', 'sunriseEpoch': 1726886986.3047202, 'sunset': '18:54:06', 'sunsetEpoch': 1726966788.9209592, 'moonphase': 0.6294364778153209, 'conditions': 'Partially cloudy', 'description': 'Becoming cloudy in the afternoon.', 'icon': 'partly-cloudy-day', 'stations': nan, 'source': 'fcst', 'City': 'New York City', 'Temp_Range': 12.084129933029036, 'Heat_Index': 78.69328608858227, 'Severity_Score': 2.7413313203575047, 'Condition_Code': nan, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Saturday', 'Is_Weekend': True, 'Health_Risk_Score': 9.195290006912863}
# 994: {'_id': ObjectId('67082952b0379fdf34f01019'), 'datetime': '2024-09-09', 'datetimeEpoch': 1725888520.0946374, 'tempmax': 89.34449319045162, 'tempmin': 62.68428416826358, 'temp': 72.01311908458757, 'feelslikemax': 87.70291211042257, 'feelslikemin': 63.345555229978295, 'feelslike': 73.34544054676196, 'dew': 56.88078006023866, 'humidity': 60.31027992997962, 'precip': 0.010856775910514, 'precipprob': 1.0414202945889954, 'precipcover': -0.3609074448676077, 'preciptype': nan, 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 16.754453339743343, 'windspeed': 9.23842214597712, 'winddir': 312.7965196890869, 'pressure': 1013.2411834772188, 'cloudcover': 12.53409438683624, 'visibility': 10.27437042043096, 'solarradiation': 306.14868872619405, 'solarenergy': 28.21200230945476, 'uvindex': 9.226183408926858, 'severerisk': 10.685192564909247, 'sunrise': '06:45:10', 'sunriseEpoch': 1725921250.039528, 'sunset': '19:23:32', 'sunsetEpoch': 1726031479.2410667, 'moonphase': 0.2060399721972967, 'conditions': 'Clear', 'description': 'Clear conditions throughout the day.', 'icon': 'clear-day', 'stations': nan, 'source': 'fcst', 'City': 'San Jose', 'Temp_Range': 24.51420315518869, 'Heat_Index': 77.3494022159497, 'Severity_Score': 3.4083730471155165, 'Condition_Code': 0.0, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Monday', 'Is_Weekend': False, 'Health_Risk_Score': 9.615947756578054}
# 995: {'_id': ObjectId('67082952b0379fdf34f0101a'), 'datetime': '2024-09-18', 'datetimeEpoch': 1726632591.6908827, 'tempmax': 76.06054558382108, 'tempmin': 64.35938718112125, 'temp': 69.0021418646212, 'feelslikemax': 77.67382309684628, 'feelslikemin': 63.51092001820757, 'feelslike': 67.00333838737069, 'dew': 59.93677637799703, 'humidity': 73.18912995767292, 'precip': 0.0846599550485508, 'precipprob': 30.567090880517146, 'precipcover': 3.481762742020263, 'preciptype': "['rain']", 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 13.864631630856165, 'windspeed': 7.435891471784491, 'winddir': 51.161203277087125, 'pressure': 1023.2844766459611, 'cloudcover': 80.51276945221578, 'visibility': 14.696975809263373, 'solarradiation': 71.4583316047323, 'solarenergy': 6.994928144854293, 'uvindex': 3.121167366667473, 'severerisk': 10.563083569398849, 'sunrise': '06:44:57', 'sunriseEpoch': 1726690767.5344625, 'sunset': '19:03:37', 'sunsetEpoch': 1726616079.1568072, 'moonphase': 0.520096053095155, 'conditions': 'Partially cloudy', 'description': 'Partly cloudy throughout the day.', 'icon': 'partly-cloudy-day', 'stations': nan, 'source': 'fcst', 'City': 'Philadelphia', 'Temp_Range': 12.88666476515724, 'Heat_Index': 71.83755780601577, 'Severity_Score': 1.9573182494350945, 'Condition_Code': nan, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Wednesday', 'Is_Weekend': False, 'Health_Risk_Score': 8.75014194400079}
# 996: {'_id': ObjectId('67082952b0379fdf34f0101b'), 'datetime': '2024-09-17', 'datetimeEpoch': 1726550178.2591555, 'tempmax': 68.40919805738676, 'tempmin': 65.93931890816431, 'temp': 66.5674095722523, 'feelslikemax': 68.95672182923013, 'feelslikemin': 64.80563549957625, 'feelslike': 65.9925263191593, 'dew': 59.0102568080488, 'humidity': 74.13740133415534, 'precip': 0.0198467112477763, 'precipprob': 6.993677387681553, 'precipcover': 4.239993829695987, 'preciptype': "['rain']", 'snow': 0.0, 'snowdepth': nan, 'windgust': 6.233441261907524, 'windspeed': 8.930235260928479, 'winddir': 274.833365168613, 'pressure': 1010.5125034170854, 'cloudcover': 14.85261051809186, 'visibility': 15.09266253541919, 'solarradiation': 282.75128284580086, 'solarenergy': 22.61997936730386, 'uvindex': 8.919897091467478, 'severerisk': 9.83876673330125, 'sunrise': '06:34:01', 'sunriseEpoch': 1726593864.3125677, 'sunset': '18:51:20', 'sunsetEpoch': 1726665823.1481676, 'moonphase': 0.4775565382490627, 'conditions': 'Clear', 'description': 'Clear conditions throughout the day.', 'icon': 'clear-day', 'stations': nan, 'source': 'fcst', 'City': 'San Diego', 'Temp_Range': 2.613629381455857, 'Heat_Index': 72.46349128664832, 'Severity_Score': 2.537412696095077, 'Condition_Code': 0.0, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Tuesday', 'Is_Weekend': False, 'Health_Risk_Score': 9.118198210752777}
# 997: {'_id': ObjectId('67082952b0379fdf34f0101c'), 'datetime': '2024-09-12', 'datetimeEpoch': 1726121997.6822324, 'tempmax': 69.75669024854497, 'tempmin': 65.28691862054913, 'temp': 65.91949220060405, 'feelslikemax': 68.15853607683025, 'feelslikemin': 63.6629423965658, 'feelslike': 67.31332240561775, 'dew': 62.02444216027467, 'humidity': 84.65048171126641, 'precip': -0.0101325022253698, 'precipprob': 7.67251858935306, 'precipcover': 0.024862696942279, 'preciptype': nan, 'snow': 0.0, 'snowdepth': nan, 'windgust': 17.387860392348312, 'windspeed': 11.082902910157276, 'winddir': 196.36169150648317, 'pressure': 1005.594740059596, 'cloudcover': 46.72186089578294, 'visibility': 14.909931114159278, 'solarradiation': 272.04369261052057, 'solarenergy': 23.83047902789889, 'uvindex': 9.0895467762213, 'severerisk': 10.502440307302235, 'sunrise': '06:30:49', 'sunriseEpoch': 1726118777.4287124, 'sunset': '18:58:05', 'sunsetEpoch': 1726232300.5494423, 'moonphase': 0.3183385379385459, 'conditions': 'Partially cloudy', 'description': 'Partly cloudy throughout the day.', 'icon': 'partly-cloudy-day', 'stations': nan, 'source': 'fcst', 'City': 'San Diego', 'Temp_Range': 4.598936354061397, 'Heat_Index': 67.56005962410542, 'Severity_Score': 3.5954702517882238, 'Condition_Code': nan, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Thursday', 'Is_Weekend': False, 'Health_Risk_Score': 9.880093305614066}
# 998: {'_id': ObjectId('67082952b0379fdf34f0101d'), 'datetime': '2024-09-14', 'datetimeEpoch': 1726283773.8442173, 'tempmax': 77.10679745520832, 'tempmin': 61.481724263434025, 'temp': 68.10656881947024, 'feelslikemax': 76.42695863320282, 'feelslikemin': 60.90152579218709, 'feelslike': 68.09430850933552, 'dew': 63.16960756488583, 'humidity': 86.86026071244493, 'precip': -0.0024396636720878, 'precipprob': 0.9869657693201868, 'precipcover': 0.1328250207518287, 'preciptype': nan, 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 15.74827031797913, 'windspeed': 8.028199990157285, 'winddir': 219.7399694549943, 'pressure': 1011.2300549301156, 'cloudcover': 12.583792993505975, 'visibility': 15.052398883218446, 'solarradiation': 271.0068845579768, 'solarenergy': 22.746817873697367, 'uvindex': 8.908550146656278, 'severerisk': 9.847928794782884, 'sunrise': '06:35:57', 'sunriseEpoch': 1726296562.7305048, 'sunset': '19:00:10', 'sunsetEpoch': 1726331361.0254638, 'moonphase': 0.3973036842307673, 'conditions': 'Clear', 'description': 'Clear conditions throughout the day.', 'icon': 'clear-day', 'stations': nan, 'source': 'fcst', 'City': 'Los Angeles', 'Temp_Range': 15.477717326555805, 'Heat_Index': 67.93043708900912, 'Severity_Score': 3.4989422443113094, 'Condition_Code': 0.0, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Saturday', 'Is_Weekend': True, 'Health_Risk_Score': 9.561602091400758}
# 999: {'_id': ObjectId('67082952b0379fdf34f0101e'), 'datetime': '2024-09-18', 'datetimeEpoch': 1726618424.5460238, 'tempmax': 90.92308027793686, 'tempmin': 79.29686763922918, 'temp': 81.63699076338789, 'feelslikemax': 94.1804225681944, 'feelslikemin': 78.07185101153438, 'feelslike': 84.9871129145816, 'dew': 73.39304500862426, 'humidity': 74.73471494689899, 'precip': 0.1516152579003476, 'precipprob': 32.11207042760594, 'precipcover': 4.673089669257601, 'preciptype': "['rain']", 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 16.61535124387185, 'windspeed': 10.479637352198475, 'winddir': 104.04335705954816, 'pressure': 1012.5075974684952, 'cloudcover': 17.31376302108133, 'visibility': 15.178379396903722, 'solarradiation': 245.190433291764, 'solarenergy': 20.8396895205759, 'uvindex': 6.904596917251116, 'severerisk': 30.395643042870027, 'sunrise': '07:08:01', 'sunriseEpoch': 1726634978.5487976, 'sunset': '19:22:23', 'sunsetEpoch': 1726687669.515567, 'moonphase': 0.5316302475058464, 'conditions': 'Clear', 'description': 'Clear conditions throughout the day with storms possible.', 'icon': 'clear-day', 'stations': nan, 'source': 'fcst', 'City': 'Houston', 'Temp_Range': 11.01787051517568, 'Heat_Index': 86.80271244158527, 'Severity_Score': 3.0400203047352656, 'Condition_Code': 0.0, 'Month': 9.0, 'Season': 'Fall', 'Day_of_Week': 'Wednesday', 'Is_Weekend': False, 'Health_Risk_Score': 10.97804447087361}

# %%
df = pd.DataFrame(list(collection.find()))
df.head()
# Out:
#                         _id    datetime  datetimeEpoch  tempmax  tempmin  \
# 0  67082952b0379fdf34f00c37  2024-09-07   1.725692e+09    106.1     91.0
# 1  67082952b0379fdf34f00c38  2024-09-08   1.725779e+09    103.9     87.0
# 2  67082952b0379fdf34f00c39  2024-09-09   1.725865e+09    105.0     83.9
# 3  67082952b0379fdf34f00c3a  2024-09-10   1.725952e+09    106.1     81.2
# 4  67082952b0379fdf34f00c3b  2024-09-11   1.726038e+09    106.1     82.1
#
#    temp  feelslikemax  feelslikemin  feelslike   dew  ...     City  \
# 0  98.5         104.0          88.1       95.9  51.5  ...  Phoenix
# 1  95.4         100.5          84.7       92.3  48.7  ...  Phoenix
# 2  94.7          99.9          81.6       90.6  41.7  ...  Phoenix
# 3  93.9         100.6          79.5       89.8  39.1  ...  Phoenix
# 4  94.0         101.0          80.0       90.0  40.1  ...  Phoenix
#
#    Temp_Range  Heat_Index  Severity_Score Condition_Code  Month  Season  \
# 0        15.1   95.918703          4.4300            NaN    9.0    Fall
# 1        16.9   92.281316          3.8800            0.0    9.0    Fall
# 2        21.1   90.599165          3.6300            0.0    9.0    Fall
# 3        24.9   89.638811          2.8512            0.0    9.0    Fall
# 4        24.0   89.760414          3.3908            0.0    9.0    Fall
#
#    Day_of_Week  Is_Weekend  Health_Risk_Score
# 0     Saturday        True          10.522170
# 1       Sunday        True          10.062332
# 2       Monday       False           9.673387
# 3      Tuesday       False           9.411519
# 4    Wednesday       False           9.515179
#
# [5 rows x 47 columns]

# %%
if "_id" in df.columns.to_list():
    df = df.drop(columns=["_id"], axis=1)

# %%
df.head()
# Out:
#      datetime  datetimeEpoch  tempmax  tempmin  temp  feelslikemax  \
# 0  2024-09-07   1.725692e+09    106.1     91.0  98.5         104.0
# 1  2024-09-08   1.725779e+09    103.9     87.0  95.4         100.5
# 2  2024-09-09   1.725865e+09    105.0     83.9  94.7          99.9
# 3  2024-09-10   1.725952e+09    106.1     81.2  93.9         100.6
# 4  2024-09-11   1.726038e+09    106.1     82.1  94.0         101.0
#
#    feelslikemin  feelslike   dew  humidity  ...     City  Temp_Range  \
# 0          88.1       95.9  51.5      21.0  ...  Phoenix        15.1
# 1          84.7       92.3  48.7      21.5  ...  Phoenix        16.9
# 2          81.6       90.6  41.7      16.9  ...  Phoenix        21.1
# 3          79.5       89.8  39.1      15.7  ...  Phoenix        24.9
# 4          80.0       90.0  40.1      15.9  ...  Phoenix        24.0
#
#    Heat_Index Severity_Score  Condition_Code  Month  Season  Day_of_Week  \
# 0   95.918703         4.4300             NaN    9.0    Fall     Saturday
# 1   92.281316         3.8800             0.0    9.0    Fall       Sunday
# 2   90.599165         3.6300             0.0    9.0    Fall       Monday
# 3   89.638811         2.8512             0.0    9.0    Fall      Tuesday
# 4   89.760414         3.3908             0.0    9.0    Fall    Wednesday
#
#    Is_Weekend  Health_Risk_Score
# 0        True          10.522170
# 1        True          10.062332
# 2       False           9.673387
# 3       False           9.411519
# 4       False           9.515179
#
# [5 rows x 46 columns]
